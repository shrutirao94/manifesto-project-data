# %% [markdown]
# # Machine Learning & Computational Text Analysis
#
# [John McLevey](johnmclevey.com)
# Winter 2018
#
# Time to get started with computational text analysis! Along the way, we will learn about applications of machine learning and natural language processing  more broadly. Like other methods, these methods are best learned by doing. So let's work through some examples. Today we are going to focus mostly on processing text at the *beginning* of a text analysis workflow. We will go from unstructured text > processed text > bag of words > feature matrix for training machine learning models.
#
# I'll begin with a brief overview of how computational text analysis relates to other methods of content analysis -- quantitative and qualitative -- with long histories in the social sciences. Then, we will get into the specifics of computational text analysis.
#
# Please create more cells (or add to this one) for your notes as I lecture. Once we are sufficiently on the same page about the high-level overview, we will start working through specific examples.
#
# In the next few classes, we will cover:
#
# - TODAY: processing text
#   - tokenization, cleaning, stemming, lemmatization, bag of words / vector space model
#   - computing IF-IDF weights
#   - part of speech tagging
# - NEXT CLASS: three different types of unsupervised methods
#   - $k$-means clustering of documents based on cosine similarity
#   - LDA topic model
#   - topic detection in semantic networks
# - NEXT CLASS: one supervised method
#   - Naïve Bayes
#   - a framework for integrating both unsupervised and supervised methods in the same text analysis project
#
# Start by reading through the flowchart below. I created it to help you get a high-level overview of the process(es) of computational text analysis, from unstructured text, to numbers, to (validated) models, to enlightenment. Or at least reasonable conclusions...
#
#
# ![](img/text_as_data.png)
#
# And here is another view on the motivations behind supervised and unsupervised learning in theory-driven social research, and on when and how they might be combined. From James Evans and Pedro Aceves (2016) "Machine Translation: Mining Text for Social Theory."
#
# ![](img/text_theory.png)
#
# And finally a view from Laura Nelson's "computational grounded theory." We will talk more about this, and Evans and Aceves (2016) in a couple of classes.
#
# ![](img/nelson.png)
#
# Let's get started.
#
# # Processing Text
#
# ### Garbage in ---> Garbage Out
#
# It is not possible to do high-quality computational text analysis without initial text processing. To illustrate some basic concepts, we will start with a very small text dataset: political party manifestos from the 2015 Canadian federal election. I've downloaded the data for the Liberals, Conservatives, New Democrats, and Greens from the [Manifesto Project](https://manifesto-project.wzb.eu). You can easily obtain data for other years, countries, and parties.
#
# The data is stored as 4 `csv` files. Let's peek at one before we do anything.
#
# If you have not already installed [nltk](https://www.nltk.org/install.html), please do it now.

# %%
import pandas as pd
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shruti/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/shruti/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
base_path = "/Users/shruti/Documents/Studies/2018/INTEG 475/Machine Learning"

LIB = pd.read_csv(base_path + '/manifesto_project_data/liberal_2015.csv', encoding = 'utf-8')
LIB[:10]
# Out:
#                                                 text  cmp_code
# 0  PLATEFORME ELECTORALE PARTI LIBERAL DU CANADA ...       NaN
# 1             ECONOMIC SECURITY FOR THE MIDDLE CLASS       NaN
# 2  A strong economy starts with a strong middle c...     408.0
# 3  Our plan offers real help to Canada's middle c...     704.0
# 4  When our middle class has more money in their ...     704.0
# 5  We will give families more money to help with ...     504.0
# 6  We will cancel tax breaks and benefits for the...     503.0
# 7  and introduce a new Canada Child Benefit to gi...     504.0
# 8  With the Canada Child Benefit, nine out of ten...     305.0
# 9  For the typical family of four, that means an ...     305.0

# %% [markdown]
# The data from the Manifesto Project includes codes (`cmp_code`) that we do not need for this particular analysis (although you should look into them, as they have been used in applications of supervised text analysis).
#
# Let's just grab the text.

# %%
def get_content(csvfile):
    df = pd.read_csv(csvfile, encoding = 'utf-8')
    text = [row['text'] for index, row in df.iterrows()]
    text = " ".join(text)
    return text

# %%
lib = get_content(base_path + '/manifesto_project_data/liberal_2015.csv')
con = get_content(base_path + '/manifesto_project_data/conservative_2015.csv')
ndp = get_content(base_path + '/manifesto_project_data/ndp_2015.csv')
gre = get_content(base_path + '/manifesto_project_data/green_2015.csv')

# %% [markdown]
# You can print out each of our party lists and check to see if the function did what it was supposed to do. I don't want to print a lot to the screen in this notebook right now, so I will just grab a small slice of characters from part way through the NDP document. (I did check the others as well...)

# %%
ndp[420:850]
# Out:
# ' age, my parents taught me and my brothers and sisters the importance of living by your values.   These values are at the heart of who I am as a husband, a father and grandfather.   As your Prime Minister, I will wake up every day focused on building the country of our dreams.   With the NDP, that means:   Bringing in quality, affordable childcare.   Strengthening our public health care system.   Ensuring a cleaner environment'

# %% [markdown]
# Our unit of analysis in this toy analysis is the manifesto from each party in 2015. Even though we have that data, we are not ready to go. We still need to break each document down to a set of tokens, process those tokens, and then construct a bag of words.
#
# We will use the word tokenizer from NLTK. Let's start with the Liberals and, once we have a workflow in place, process the other parties as well.

# %%
lib_tok = word_tokenize(lib)
lib_tok[:10]
# Out:
# ['PLATEFORME',
#  'ELECTORALE',
#  'PARTI',
#  'LIBERAL',
#  'DU',
#  'CANADA',
#  '2015',
#  'ECONOMIC',
#  'SECURITY',
#  'FOR']

# %% [markdown]
# As you can see, we have broken the Liberal document down to individual tokens. Since we used a word tokenizer, you shouldn't be surprised to see a list of individual words! (If we use a sentence tokenizer, it would have split the document into sentences...)
#
# From here, it's easy to quantify our text, turning it into a simple "[bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model)."
#
# **Spoiler**: we haven't done enough processing yet, so this bag of words is going to suck. Garbage in, garbage out.
#
# I'm not going to bother assigning the results to a variable, let's just see what it looks like by peaking at the top _n_ with the `most_common` method for counter objects.

# %%
Counter(lib_tok).most_common(40)
# Out:
# [(',', 857),
#  ('and', 754),
#  ('.', 749),
#  ('to', 648),
#  ('the', 608),
#  ('will', 557),
#  ('We', 361),
#  ('of', 322),
#  ('in', 271),
#  ('for', 228),
#  ('a', 227),
#  ('that', 207),
#  ('Canada', 167),
#  ('our', 163),
#  ('more', 151),
#  ('with', 150),
#  ('Canadians', 136),
#  ("'s", 112),
#  ('we', 109),
#  ('make', 94),
#  ('is', 91),
#  ('on', 91),
#  ('new', 88),
#  ('$', 85),
#  ('by', 85),
#  ('are', 78),
#  ('help', 74),
#  ('work', 72),
#  ('their', 71),
#  ('also', 71),
#  ('government', 70),
#  ('it', 64),
#  ('be', 63),
#  ('support', 62),
#  ('an', 61),
#  ('not', 60),
#  ('year', 59),
#  ('Canadian', 57),
#  ('all', 55),
#  ('million', 53)]

# %% [markdown]
# We didn't learn much about the Liberal document from that peek at the bag of words, did we?
#
# There are a lot of things that can and should be different. Words counts are split if a word is sometimes capitalized and sometimes not. Many of these words are not useful when they are removed from their semantic context (e.g. "and", "the", "a"). We don't need punctuation. Etc.
#
# Fortunately, a bit of pre-processing will get us a _much_ better bag of words.
#
# Here, with a bit of list comprehension to make things more concise, is some processing that will return any alpha characters as lower case _unless_ they show up in NLTK's list of English [stop words](https://en.wikipedia.org/wiki/Stop_words). We could have used another list, but the NLTK list is good.
#
# Sometimes you should keep stop words, sometimes you shouldn't. As always: it depends.

# %%
without_stops = [t.lower() for t in lib_tok if t.isalpha()
                 and t not in stopwords.words('english')]

# %% [markdown]
# Let's take a quick peek at the top _n_ words in our new bag of words.

# %%
Counter(without_stops).most_common(40)
# Out:
# [('we', 362),
#  ('canada', 178),
#  ('canadians', 142),
#  ('new', 96),
#  ('make', 94),
#  ('government', 79),
#  ('help', 76),
#  ('work', 72),
#  ('also', 71),
#  ('support', 65),
#  ('canadian', 60),
#  ('year', 59),
#  ('harper', 53),
#  ('million', 53),
#  ('ensure', 53),
#  ('communities', 52),
#  ('stephen', 48),
#  ('to', 48),
#  ('invest', 47),
#  ('families', 43),
#  ('provide', 43),
#  ('national', 43),
#  ('federal', 41),
#  ('infrastructure', 40),
#  ('this', 39),
#  ('need', 37),
#  ('funding', 37),
#  ('investments', 36),
#  ('veterans', 36),
#  ('provinces', 35),
#  ('first', 35),
#  ('benefit', 34),
#  ('including', 34),
#  ('nations', 34),
#  ('economy', 32),
#  ('care', 32),
#  ('service', 32),
#  ('security', 31),
#  ('territories', 31),
#  ('public', 31)]

# %% [markdown]
# Much better! Still, we could benefit from [stemming](https://en.wikipedia.org/wiki/Stemming) or [lemmatization](https://en.wikipedia.org/wiki/Lemmatisation). Stemming reduces words to their stem, while lemmatization groups words together into their most basic dictionary form. Depending on your case, stemming or lemmatization will allow you to group together related words that have different surface forms (e.g. 'run,' 'running', and 'runners', or 'sick' and 'ill'). This will improve the quality of any models we train.
#
# Stemmed words are a little less readable because word stems are typically not words we actually use. Lemmas are readable because they are valid words. The tradeoff is that stems are faster to compute and the validity ends up being comparable to lemmatization. Both methods have been shown to work very well for computational text analysis. Unless you have a good reason not to (e.g. variations on a word carry a lot of meaning in your particular case), then you should just pick one.
#
# Let's try lemmatization for now. We will add it to a new processing text function that combines our tokenization and processing steps from previous cells. We will design it so that it accepts text directly from our `get_content` function.

# %%
def process_text(text):
    tokens = [w for w in word_tokenize(text.lower()) if w.isalpha()]
    no_stop_words = [t for t in tokens if t not in stopwords.words('english')]
    wordnet_lemmatizer = WordNetLemmatizer()
    lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stop_words]
    bag_of_words = Counter(lemmatized)
    return bag_of_words

# %% [markdown]
# Good news, everyone! We now have an easy way to get a bag of words from these political parties. Let's take a look at the most frequently occurring words from each party document.
#
# ![](https://media.giphy.com/media/3o7abA4a0QCXtSxGN2/giphy.gif)

# %%
lib_bow = process_text(lib)
con_bow = process_text(con)
ndp_bow = process_text(ndp)
gre_bow = process_text(gre)

# %%
print(lib_bow.most_common(100))
# Out:
# [('canadian', 202), ('canada', 178), ('make', 101), ('new', 96), ('year', 87), ('government', 86), ('help', 78), ('work', 77), ('also', 71), ('support', 70), ('community', 63), ('investment', 63), ('family', 62), ('benefit', 60), ('service', 57), ('million', 56), ('harper', 53), ('ensure', 53), ('need', 50), ('stephen', 48), ('invest', 47), ('nation', 45), ('provide', 43), ('national', 43), ('program', 41), ('federal', 41), ('job', 40), ('infrastructure', 40), ('veteran', 40), ('economy', 37), ('funding', 37), ('province', 35), ('first', 35), ('including', 34), ('child', 34), ('tax', 33), ('care', 32), ('territory', 32), ('security', 31), ('plan', 31), ('public', 31), ('access', 30), ('student', 30), ('create', 29), ('change', 29), ('health', 29), ('protect', 29), ('better', 26), ('time', 26), ('increase', 26), ('housing', 26), ('election', 26), ('give', 25), ('one', 25), ('people', 25), ('economic', 24), ('income', 24), ('affordable', 24), ('right', 24), ('class', 23), ('opportunity', 23), ('training', 23), ('easier', 23), ('indigenous', 23), ('information', 23), ('international', 23), ('middle', 22), ('restore', 22), ('fund', 22), ('process', 22), ('end', 21), ('young', 21), ('good', 21), ('review', 21), ('system', 21), ('part', 21), ('per', 20), ('project', 20), ('member', 20), ('education', 20), ('united', 20), ('force', 20), ('expand', 19), ('trade', 19), ('decision', 19), ('available', 19), ('clean', 19), ('cost', 18), ('percent', 18), ('employment', 18), ('technology', 18), ('immediately', 18), ('important', 18), ('world', 18), ('relationship', 18), ('mtis', 18), ('refugee', 18), ('grow', 17), ('introduce', 17), ('get', 17)]

# %%
print(con_bow.most_common(100))
# Out:
# [('canadian', 244), ('canada', 165), ('government', 163), ('conservative', 121), ('tax', 114), ('new', 108), ('family', 101), ('job', 85), ('year', 80), ('support', 70), ('economy', 69), ('business', 69), ('plan', 68), ('continue', 58), ('program', 54), ('country', 49), ('help', 48), ('child', 48), ('million', 47), ('world', 46), ('budget', 40), ('senior', 40), ('investment', 40), ('market', 38), ('also', 38), ('one', 37), ('make', 36), ('protect', 34), ('balanced', 33), ('economic', 32), ('small', 32), ('work', 31), ('industry', 31), ('worker', 30), ('home', 30), ('development', 30), ('need', 28), ('product', 28), ('system', 27), ('benefit', 26), ('good', 26), ('billion', 26), ('saving', 26), ('create', 25), ('trade', 25), ('including', 25), ('security', 25), ('income', 24), ('relief', 23), ('infrastructure', 23), ('sector', 23), ('credit', 23), ('community', 22), ('percent', 22), ('research', 22), ('project', 22), ('federal', 21), ('service', 21), ('opportunity', 21), ('part', 21), ('making', 21), ('technology', 21), ('significant', 20), ('since', 20), ('life', 20), ('grant', 20), ('foreign', 20), ('next', 19), ('right', 19), ('record', 19), ('better', 19), ('low', 19), ('legislation', 19), ('ensure', 19), ('increase', 19), ('manufacturing', 19), ('global', 18), ('four', 18), ('working', 18), ('per', 18), ('important', 18), ('financial', 18), ('isi', 18), ('time', 17), ('keep', 17), ('liberal', 17), ('way', 17), ('every', 17), ('build', 17), ('first', 17), ('take', 17), ('fund', 17), ('spending', 16), ('provide', 16), ('future', 16), ('cost', 16), ('made', 16), ('helping', 16), ('providing', 16), ('mean', 16)]

# %%
print(ndp_bow.most_common(100))
# Out:
# [('canada', 167), ('ndp', 163), ('canadian', 162), ('government', 99), ('ensure', 73), ('health', 63), ('plan', 62), ('care', 60), ('support', 60), ('community', 59), ('year', 58), ('work', 57), ('make', 57), ('harper', 56), ('conservative', 55), ('new', 53), ('family', 52), ('stephen', 51), ('woman', 50), ('program', 48), ('help', 48), ('need', 48), ('indigenous', 44), ('national', 44), ('change', 41), ('federal', 41), ('access', 39), ('province', 39), ('job', 37), ('tax', 37), ('funding', 36), ('also', 36), ('public', 35), ('benefit', 35), ('country', 34), ('million', 34), ('investment', 34), ('ensuring', 32), ('home', 32), ('first', 31), ('service', 31), ('improve', 30), ('infrastructure', 29), ('act', 29), ('working', 29), ('cut', 28), ('veteran', 28), ('including', 28), ('child', 27), ('provide', 27), ('living', 26), ('affordable', 26), ('economy', 26), ('create', 26), ('protect', 26), ('economic', 26), ('take', 25), ('right', 25), ('worker', 25), ('get', 24), ('youth', 24), ('many', 24), ('life', 23), ('business', 23), ('time', 23), ('sector', 23), ('liberal', 23), ('disability', 23), ('every', 22), ('pay', 22), ('poverty', 22), ('one', 22), ('nation', 22), ('creating', 21), ('step', 21), ('better', 20), ('young', 20), ('end', 20), ('senior', 20), ('providing', 20), ('investing', 20), ('action', 19), ('development', 19), ('making', 19), ('four', 19), ('opportunity', 19), ('mandate', 19), ('invest', 18), ('world', 18), ('climate', 18), ('legislation', 18), ('fund', 18), ('people', 18), ('territory', 18), ('increase', 18), ('housing', 18), ('decade', 17), ('reduce', 17), ('small', 17), ('law', 17)]

# %%
print(gre_bow.most_common(100))
# Out:
# [('canadian', 135), ('canada', 113), ('government', 46), ('work', 44), ('green', 44), ('community', 43), ('ensure', 42), ('public', 37), ('first', 37), ('need', 35), ('care', 34), ('time', 34), ('party', 33), ('health', 32), ('system', 31), ('national', 30), ('job', 29), ('new', 29), ('economy', 28), ('climate', 28), ('make', 27), ('nation', 27), ('plan', 25), ('must', 24), ('bill', 24), ('people', 23), ('local', 23), ('service', 22), ('parliament', 22), ('u', 20), ('year', 20), ('sustainable', 20), ('energy', 20), ('together', 19), ('country', 19), ('funding', 19), ('create', 19), ('mp', 19), ('good', 18), ('harper', 18), ('infrastructure', 18), ('support', 17), ('strategy', 17), ('economic', 16), ('education', 16), ('access', 16), ('rail', 16), ('every', 15), ('policy', 15), ('business', 15), ('tax', 15), ('housing', 15), ('federal', 15), ('law', 15), ('oil', 15), ('building', 14), ('vote', 14), ('family', 14), ('resource', 14), ('percent', 14), ('change', 14), ('right', 14), ('one', 13), ('act', 13), ('political', 13), ('use', 13), ('safe', 12), ('election', 12), ('industry', 12), ('providing', 12), ('provide', 12), ('take', 12), ('level', 12), ('way', 12), ('child', 12), ('benefit', 12), ('home', 12), ('end', 12), ('know', 11), ('future', 11), ('many', 11), ('also', 11), ('small', 11), ('world', 11), ('creating', 11), ('investment', 11), ('technology', 11), ('fund', 11), ('mean', 11), ('even', 11), ('defend', 11), ('senior', 11), ('build', 10), ('democracy', 10), ('leader', 10), ('province', 10), ('help', 10), ('conservative', 10), ('critical', 10), ('cut', 10)]

# %% [markdown]
# If you know anything about those four political parties and the campaigns they ran in 2015, you can probably see that our processed text is already showing us some important differences. But we are _just getting started..._
#
# If we wanted to, we could now transform our bag of words into a document-term feature matrix. In this matrix, each document in our analysis (currently only 4!) would be a row, and every feature would be a column. In this and other computational text analyses, the features are unique words from the corpus. If we were to continue with this toy example, how many features would there be in our matrix? However many unique tokens there are in our entire corpus! If there are 1 million tokens, then our matrix would have 1 million features.
#
# Unless we compute some statistic, the cells in our matrix will just be raw counts of the number of times a given token is in a given document. For example, if the token "education" appears in a document 'liberal' 6 times, then that cell in the matrix will be 6.
#
# This kind of matrix is very common, and very useful. The basic idea, as you might have guessed, is that words that appear more frequently in a document are more important to that document. However, some words (like "canada" or "government") are common but not especially meaningful because they appear frequently across all documents. Instead of raw counts, we may want the cells of our matrix to be some sort of weight that better measures how important that word is to the document. That's where TF-IDF comes in.
#
# # Measuring Word Importance with TF-IDF
#
# One thing you may have noticed in the bags of words above is that some words (e.g. "canada", 'government') are so common across the documents in our corpus that they don't help us understand important differences in what is talked about in each document. For the same reasons that we removed stop words, we may want to pay less attention to words that are very common across documents in our corpus, and pay more attention to words that appear frequently within documents and less frequently across the corpus. That's what [term frequency - inverse document frequency](https://en.wikipedia.org/wiki/Tf–idf), or TF-IDF, is for.
#
# The tf-idf statistic measures the importance of a word in a document in a larger corpus. Formally, it looks like this:
#
# <!-- $$w_i,_j = tf_i,_j * log\Big(\frac{N}{df_i}\Big)$$ -->
#
# Where the tf-idf weight $w$ for word $i$ in document $j$ is equal to the term frequency multiplied by the inverse document frequency. Clear as mud?
#
# <!-- The term frequency $tf_i,_j$ is just the number of times the word $i$ appears in document $j$. The inverse document frequency the log of the total number of documents in the corpus divided by the number of documents that the word $i$ appears in. TF-IDF is just the product of those two numbers. -->
#
# TF-IDF can be computed easily using Python packages like [gensim](https://radimrehurek.com/gensim/) and [scikit-learn](http://scikit-learn.org/stable/). Let's take a look at both using a more serious example instead of this toy example. We will do so in another notebook ('unsupervised.ipynb').
#
# Before we do that, let's take a quick look at two more text processing methods: parts-of-speech tagging and named entity recognition.
#
# # Part-of-speech Tagging
#
# Computational linguists have developed highly accurate probabilistic approaches to chunking sentences into their parts of speech, such as nouns, proper nouns adjectives, verbs, adverbs, etc.
#
# ![](img/evans_aceves.png)

# %%
import spacy
nlp = spacy.load('en')

# %%
c_nlp = nlp(con)
g_nlp = nlp(gre)
l_nlp = nlp(lib)
n_nlp = nlp(ndp)

# %%
for word in l_nlp:
    print(word, word.pos_)
# Out:
# PLATEFORME ADP
# ELECTORALE PROPN
# PARTI PROPN
# LIBERAL ADJ
# DU PROPN
# CANADA PROPN
# 2015 NUM
# ECONOMIC PROPN
# SECURITY NOUN
# FOR ADP
# THE DET
# MIDDLE ADJ
# CLASS NOUN
# A DET
# strong ADJ
# economy NOUN
# starts VERB
# with ADP
# a DET
# strong ADJ
# middle ADJ
# class NOUN
# . PUNCT
# Our ADJ
# plan NOUN
# offers VERB
# real ADJ
# help NOUN
# to ADP
# Canada PROPN
# 's PART
# middle ADJ
# class NOUN
# and CCONJ
# all ADJ
# those DET
# working VERB
# hard ADV
# to PART
# join VERB
# it PRON
# . PUNCT
# When ADV
# our ADJ
# middle ADJ
# class NOUN
# has VERB
# more ADJ
# money NOUN
# in ADP
# their ADJ
# pockets NOUN
# to PART
# save VERB
# , PUNCT
# invest VERB
# , PUNCT
# and CCONJ
# grow VERB
# the DET
# economy NOUN
# , PUNCT
# we PRON
# all DET
# benefit VERB
# . PUNCT
# We PRON
# will VERB
# give VERB
# families NOUN
# more ADJ
# money NOUN
# to PART
# help VERB
# with ADP
# the DET
# high ADJ
# cost NOUN
# of ADP
# raising VERB
# their ADJ
# kids NOUN
# . PUNCT
# We PRON
# will VERB
# cancel VERB
# tax NOUN
# breaks NOUN
# and CCONJ
# benefits NOUN
# for ADP
# the DET
# wealthy ADJ
# including VERB
# the DET
# Universal PROPN
# Child PROPN
# Care PROPN
# Benefit PROPN
# € PUNCT
# “ PUNCT
# and CCONJ
# introduce VERB
# a DET
# new ADJ
# Canada PROPN
# Child PROPN
# Benefit PROPN
# to PART
# give VERB
# Canadian ADJ
# families NOUN
# more ADJ
# money NOUN
# to PART
# raise VERB
# their ADJ
# kids NOUN
# . PUNCT
# With ADP
# the DET
# Canada PROPN
# Child PROPN
# Benefit PROPN
# , PUNCT
# nine NUM
# out ADP
# of ADP
# ten NUM
# Canadian ADJ
# families NOUN
# will VERB
# receive VERB
# more ADJ
# than ADP
# under ADP
# Stephen PROPN
# Harper PROPN
# 's PART
# confusing ADJ
# collection NOUN
# of ADP
# child NOUN
# benefit NOUN
# programs NOUN
# . PUNCT
# For ADP
# the DET
# typical ADJ
# family NOUN
# of ADP
# four NUM
# , PUNCT
# that ADJ
# means VERB
# an DET
# additional ADJ
# $ SYM
# 2,500 NUM
# in ADP
# help NOUN
# , PUNCT
# tax NOUN
# - PUNCT
# free ADJ
# , PUNCT
# every DET
# year NOUN
# . PUNCT
# Because ADP
# the DET
# Canada PROPN
# Child PROPN
# Benefit PROPN
# is VERB
# tax NOUN
# - PUNCT
# free ADJ
# and CCONJ
# tied VERB
# to PART
# income NOUN
# , PUNCT
# it PRON
# also ADV
# provides VERB
# greater ADJ
# support NOUN
# to ADP
# those DET
# who NOUN
# need VERB
# help VERB
# the DET
# most ADV
# : PUNCT
# single ADJ
# - PUNCT
# parent NOUN
# families NOUN
# and CCONJ
# low ADJ
# - PUNCT
# income NOUN
# families NOUN
# . PUNCT
# Our ADJ
# plan NOUN
# will VERB
# lift VERB
# 315,000 NUM
# Canadian ADJ
# children NOUN
# out ADP
# of ADP
# poverty NOUN
# . PUNCT
# Stephen PROPN
# Harper PROPN
# thinks VERB
# that ADP
# government NOUN
# should VERB
# provide VERB
# child NOUN
# support NOUN
# payments NOUN
# to ADP
# millionaires NOUN
# . PUNCT
# We PRON
# will VERB
# end VERB
# that ADP
# unfair ADJ
# giveaway NOUN
# . PUNCT
# MIDDLE ADJ
# CLASS NOUN
# TAX NOUN
# CUT PROPN
# We PRON
# will VERB
# give VERB
# middle ADJ
# class NOUN
# Canadians PROPN
# a DET
# tax NOUN
# break NOUN
# , PUNCT
# by ADP
# making VERB
# taxes NOUN
# more ADV
# fair ADJ
# . PUNCT
# When ADV
# middle ADJ
# class NOUN
# Canadians PROPN
# have VERB
# more ADJ
# money NOUN
# in ADP
# their ADJ
# pockets NOUN
# to PART
# save VERB
# , PUNCT
# invest VERB
# , PUNCT
# and CCONJ
# grow VERB
# the DET
# economy NOUN
# , PUNCT
# we PRON
# all DET
# benefit VERB
# . PUNCT
# We PRON
# will VERB
# cut VERB
# the DET
# middle ADJ
# income NOUN
# tax NOUN
# bracket NOUN
# to ADP
# 20.5 NUM
# percent NOUN
# from ADP
# 22 NUM
# percent NOUN
# a DET
# seven NUM
# percent NOUN
# reduction NOUN
# . PUNCT
# Canadians NOUN
# with ADP
# taxable ADJ
# annual ADJ
# income NOUN
# between ADP
# $ SYM
# 44,700 NUM
# and CCONJ
# $ SYM
# 89,401 NUM
# will VERB
# see VERB
# their ADJ
# income NOUN
# tax NOUN
# rate NOUN
# fall NOUN
# . PUNCT
# This DET
# tax NOUN
# relief NOUN
# is VERB
# worth ADJ
# up ADP
# to PART
# $ SYM
# 670 NUM
# per ADP
# person NOUN
# , PUNCT
# per ADP
# year NOUN
# or CCONJ
# $ SYM
# 1,340 NUM
# for ADP
# a DET
# two NUM
# - PUNCT
# income NOUN
# household NOUN
# . PUNCT
# To PART
# pay VERB
# for ADP
# this DET
# tax NOUN
# cut NOUN
# , PUNCT
# we PRON
# will VERB
# ask VERB
# the DET
# wealthiest ADJ
# one NUM
# percent NOUN
# of ADP
# Canadians PROPN
# to PART
# give VERB
# a DET
# little ADJ
# more ADJ
# . PUNCT
# We PRON
# will VERB
# introduce VERB
# a DET
# new ADJ
# tax NOUN
# bracket NOUN
# of ADP
# 33 NUM
# percent NOUN
# for ADP
# individuals NOUN
# earning VERB
# more ADJ
# than ADP
# $ SYM
# 200,000 NUM
# each DET
# year NOUN
# . PUNCT
# ENDING VERB
# UNFAIR PROPN
# TAX NOUN
# BREAKS NOUN
# We PRON
# will VERB
# cancel VERB
# income NOUN
# splitting NOUN
# and CCONJ
# other ADJ
# tax NOUN
# breaks NOUN
# and CCONJ
# benefits NOUN
# for ADP
# the DET
# wealthy ADJ
# . PUNCT
# Income NOUN
# splitting NOUN
# costs VERB
# the DET
# federal ADJ
# government NOUN
# $ SYM
# 2 NUM
# billion NUM
# a DET
# year NOUN
# but CCONJ
# delivers VERB
# benefits NOUN
# to ADP
# only ADV
# a DET
# few ADJ
# . PUNCT
# It PRON
# will VERB
# not ADV
# create VERB
# a DET
# single ADJ
# job NOUN
# . PUNCT
# It PRON
# will VERB
# not ADV
# give VERB
# one NUM
# young ADJ
# person NOUN
# an DET
# opportunity NOUN
# to PART
# get VERB
# ahead ADV
# . PUNCT
# Income NOUN
# splitting NOUN
# delivers VERB
# no DET
# benefits NOUN
# to ADP
# working VERB
# parents NOUN
# who NOUN
# earn VERB
# similar ADJ
# salaries NOUN
# , PUNCT
# no DET
# benefits NOUN
# to ADP
# single ADJ
# parents NOUN
# , PUNCT
# and CCONJ
# no DET
# benefits NOUN
# to ADP
# Canadians PROPN
# who NOUN
# do VERB
# not ADV
# have VERB
# kids NOUN
# . PUNCT
# All DET
# told VERB
# , PUNCT
# income NOUN
# splitting NOUN
# benefits NOUN
# only ADV
# about ADV
# 15 NUM
# percent NOUN
# of ADP
# Canadian ADJ
# households NOUN
# . PUNCT
# We PRON
# will VERB
# cancel VERB
# Stephen PROPN
# Harper PROPN
# 's PART
# tax NOUN
# breaks NOUN
# for ADP
# the DET
# wealthy ADJ
# , PUNCT
# to PART
# give VERB
# Canadian ADJ
# families NOUN
# more ADJ
# money NOUN
# to PART
# raise VERB
# their ADJ
# children NOUN
# . PUNCT
# OPPORTUNITIES NOUN
# FOR ADP
# YOUNG ADJ
# CANADIANS NOUN
# We PRON
# will VERB
# invest VERB
# to PART
# create VERB
# more ADJ
# jobs NOUN
# and CCONJ
# better ADJ
# opportunities NOUN
# for ADP
# young ADJ
# Canadians PROPN
# . PUNCT
# After ADP
# ten NUM
# years NOUN
# under ADP
# Stephen PROPN
# Harper PROPN
# , PUNCT
# good ADJ
# - PUNCT
# quality NOUN
# job NOUN
# opportunities NOUN
# for ADP
# young ADJ
# Canadians PROPN
# are VERB
# tougher ADJ
# and CCONJ
# tougher ADJ
# to PART
# find VERB
# . PUNCT
# Faced VERB
# with ADP
# high ADJ
# unemployment NOUN
# and CCONJ
# underemployment ADJ
# , PUNCT
# many ADJ
# young ADJ
# people NOUN
# have VERB
# stopped VERB
# looking VERB
# for ADP
# work NOUN
# altogether ADV
# . PUNCT
# This DET
# is VERB
# hard ADJ
# for ADP
# both DET
# young ADJ
# people NOUN
# and CCONJ
# their ADJ
# families NOUN
# . PUNCT
# Many ADJ
# parents NOUN
# are VERB
# seeing VERB
# their ADJ
# household NOUN
# debt NOUN
# rise NOUN
# and CCONJ
# retirement NOUN
# savings NOUN
# dwindle VERB
# as ADP
# they PRON
# struggle VERB
# to PART
# support VERB
# their ADJ
# grown ADJ
# children NOUN
# , PUNCT
# who NOUN
# often ADV
# return VERB
# home ADV
# . PUNCT
# It PRON
# is VERB
# time NOUN
# to PART
# invest VERB
# in ADP
# young ADJ
# Canadians PROPN
# to PART
# help VERB
# them PRON
# get VERB
# the DET
# work NOUN
# experience NOUN
# they PRON
# will VERB
# need VERB
# to PART
# start VERB
# their ADJ
# careers NOUN
# and CCONJ
# contribute VERB
# fully ADV
# to ADP
# our ADJ
# economy NOUN
# . PUNCT
# We PRON
# will VERB
# create VERB
# 40,000 NUM
# good ADJ
# youth NOUN
# jobs NOUN
# including VERB
# 5,000 NUM
# youth NOUN
# green ADJ
# jobs NOUN
# each DET
# year NOUN
# for ADP
# the DET
# next ADJ
# three NUM
# years NOUN
# , PUNCT
# by ADP
# investing VERB
# $ SYM
# 300 NUM
# million NUM
# more ADJ
# in ADP
# the DET
# renewed VERB
# Youth PROPN
# Employment PROPN
# Strategy PROPN
# . PUNCT
# We PRON
# will VERB
# more ADV
# than ADP
# double ADJ
# the DET
# almost ADV
# 11,000 NUM
# Canadians PROPN
# who NOUN
# access VERB
# Skills PROPN
# Link VERB
# each DET
# year NOUN
# . PUNCT
# This DET
# program NOUN
# helps VERB
# young ADJ
# Canadians PROPN
# including VERB
# Aboriginal ADJ
# and CCONJ
# disabled ADJ
# youth NOUN
# make VERB
# a DET
# more ADV
# successful ADJ
# transition NOUN
# to ADP
# the DET
# workplace NOUN
# . PUNCT
# After ADP
# this DET
# initial ADJ
# three NUM
# - PUNCT
# year NOUN
# boost NOUN
# in ADP
# funding NOUN
# , PUNCT
# we PRON
# will VERB
# set VERB
# the DET
# renewed VERB
# Youth PROPN
# Employment PROPN
# Strategy PROPN
# 's PART
# funding NOUN
# level NOUN
# at ADP
# $ SYM
# 385 NUM
# million NUM
# per ADP
# year NOUN
# a DET
# $ SYM
# 50 NUM
# million NUM
# increase NOUN
# from ADP
# 2015/16 NUM
# . PUNCT
# We PRON
# will VERB
# invest VERB
# $ SYM
# 40 NUM
# million NUM
# each DET
# year NOUN
# to PART
# help VERB
# employers NOUN
# create VERB
# more ADJ
# co NOUN
# - PUNCT
# op NOUN
# placements NOUN
# for ADP
# students NOUN
# in ADP
# science NOUN
# , PUNCT
# technology NOUN
# , PUNCT
# engineering NOUN
# , PUNCT
# mathematics NOUN
# , PUNCT
# and CCONJ
# business NOUN
# programs NOUN
# . PUNCT
# And CCONJ
# to PART
# encourage VERB
# companies NOUN
# to PART
# hire VERB
# young ADJ
# Canadians PROPN
# for ADP
# permanent ADJ
# positions NOUN
# , PUNCT
# we PRON
# will VERB
# also ADV
# offer VERB
# a DET
# 12-month NUM
# break NOUN
# on ADP
# Employment PROPN
# Insurance PROPN
# premiums NOUN
# . PUNCT
# We PRON
# will VERB
# waive VERB
# employer NOUN
# premiums NOUN
# for ADP
# all ADJ
# those DET
# between ADP
# the DET
# ages NOUN
# of ADP
# 18 NUM
# and CCONJ
# 24 NUM
# who NOUN
# are VERB
# hired VERB
# into ADP
# a DET
# permanent ADJ
# position NOUN
# in ADP
# 2016 NUM
# , PUNCT
# 2017 NUM
# , PUNCT
# or CCONJ
# 2018 NUM
# . PUNCT
# We PRON
# will VERB
# also ADV
# work VERB
# with ADP
# provinces NOUN
# , PUNCT
# territories NOUN
# , PUNCT
# and CCONJ
# post NOUN
# - PUNCT
# secondary ADJ
# institutions NOUN
# to PART
# develop VERB
# or CCONJ
# expand VERB
# Pre PROPN
# - PUNCT
# Apprenticeship PROPN
# Training PROPN
# Programs PROPN
# . PUNCT
# This DET
# will VERB
# provide VERB
# up ADP
# to PART
# $ SYM
# 10 NUM
# million NUM
# per ADP
# year NOUN
# to PART
# help VERB
# young ADJ
# Canadians PROPN
# gain VERB
# the DET
# skills NOUN
# they PRON
# need VERB
# to PART
# enter VERB
# high ADJ
# - PUNCT
# demand NOUN
# trades NOUN
# . PUNCT
# We PRON
# will VERB
# end VERB
# the DET
# rule NOUN
# that ADJ
# discriminates VERB
# against ADP
# new ADJ
# workers NOUN
# and CCONJ
# those DET
# re NOUN
# - PUNCT
# entering VERB
# the DET
# workforce NOUN
# by ADP
# requiring VERB
# them PRON
# to PART
# accumulate VERB
# 910 NUM
# hours NOUN
# of ADP
# work NOUN
# to PART
# qualify VERB
# for ADP
# Employment PROPN
# Insurance PROPN
# benefits NOUN
# , PUNCT
# including VERB
# training NOUN
# support NOUN
# . PUNCT
# We PRON
# will VERB
# invest VERB
# $ SYM
# 25 NUM
# million NUM
# per ADP
# year NOUN
# in ADP
# a DET
# restored VERB
# Youth PROPN
# Service PROPN
# Program PROPN
# , PUNCT
# to PART
# give VERB
# young ADJ
# Canadians PROPN
# valuable ADJ
# work NOUN
# and CCONJ
# life NOUN
# experience NOUN
# , PUNCT
# and CCONJ
# provide VERB
# communities NOUN
# with ADP
# the DET
# help NOUN
# required VERB
# for ADP
# much ADV
# - PUNCT
# needed VERB
# projects NOUN
# . PUNCT
# RETIREMENT PROPN
# SECURITY PROPN
# We PRON
# will VERB
# provide VERB
# Canadians PROPN
# with ADP
# a DET
# more ADV
# secure ADJ
# retirement NOUN
# . PUNCT
# After ADP
# a DET
# lifetime NOUN
# of ADP
# hard ADJ
# work NOUN
# , PUNCT
# Canadians PROPN
# have VERB
# earned VERB
# a DET
# secure ADJ
# and CCONJ
# dignified ADJ
# retirement NOUN
# , PUNCT
# but CCONJ
# too ADV
# many ADJ
# now ADV
# wonder VERB
# when ADV
# or CCONJ
# even ADV
# if ADP
# that DET
# will VERB
# happen VERB
# . PUNCT
# We PRON
# will VERB
# help VERB
# Canadians PROPN
# realize VERB
# their ADJ
# goal NOUN
# of ADP
# a DET
# secure ADJ
# retirement NOUN
# . PUNCT
# That DET
# security NOUN
# starts VERB
# with ADP
# a DET
# strong ADJ
# and CCONJ
# stable ADJ
# pension NOUN
# program NOUN
# . PUNCT
# We PRON
# will VERB
# work VERB
# with ADP
# the DET
# provinces NOUN
# and CCONJ
# territories NOUN
# , PUNCT
# workers NOUN
# , PUNCT
# employers NOUN
# , PUNCT
# and CCONJ
# retiree NOUN
# organizations NOUN
# to PART
# enhance VERB
# the DET
# Canada PROPN
# Pension PROPN
# Plan PROPN
# . PUNCT
# We PRON
# will VERB
# not ADV
# end VERB
# pension NOUN
# income NOUN
# splitting NOUN
# for ADP
# seniors NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# restore VERB
# the DET
# eligibility NOUN
# age NOUN
# for ADP
# Old PROPN
# Age PROPN
# Security PROPN
# and CCONJ
# the DET
# Guaranteed PROPN
# Income PROPN
# Supplement PROPN
# to ADP
# 65 NUM
# , PUNCT
# putting VERB
# an DET
# average NOUN
# of ADP
# $ SYM
# 13,000 NUM
# into ADP
# the DET
# pockets NOUN
# of ADP
# the DET
# lowest ADJ
# income NOUN
# Canadians PROPN
# each DET
# year NOUN
# , PUNCT
# as ADP
# they PRON
# become VERB
# seniors NOUN
# . PUNCT
# We PRON
# will VERB
# help VERB
# to PART
# lift VERB
# hundreds NOUN
# of ADP
# thousands NOUN
# of ADP
# seniors NOUN
# out ADP
# of ADP
# poverty NOUN
# by ADP
# increasing VERB
# the DET
# Guaranteed PROPN
# Income PROPN
# Supplement PROPN
# for ADP
# single ADJ
# low ADJ
# - PUNCT
# income NOUN
# seniors NOUN
# by ADP
# ten NUM
# percent NOUN
# . PUNCT
# This DET
# will VERB
# give VERB
# one NUM
# million NUM
# of ADP
# our ADJ
# most ADV
# vulnerable ADJ
# seniors NOUN
# who NOUN
# are VERB
# often ADV
# women NOUN
# almost ADV
# $ SYM
# 1,000 NUM
# more ADJ
# each DET
# year NOUN
# . PUNCT
# Because ADP
# many ADJ
# seniors NOUN
# live VERB
# on ADP
# fixed VERB
# incomes NOUN
# , PUNCT
# we PRON
# will VERB
# introduce VERB
# a DET
# new ADJ
# Seniors PROPN
# Price PROPN
# Index PROPN
# to PART
# make VERB
# sure ADJ
# that ADP
# Old PROPN
# Age PROPN
# Security PROPN
# and CCONJ
# the DET
# Guaranteed PROPN
# Income PROPN
# Supplement PROPN
# benefits NOUN
# keep VERB
# up PART
# with ADP
# seniors NOUN
# ' PART
# actual ADJ
# rising VERB
# costs NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# make VERB
# the DET
# Compassionate PROPN
# Care PROPN
# Benefit PROPN
# more ADV
# flexible ADJ
# and CCONJ
# easier ADJ
# to PART
# access VERB
# , PUNCT
# so ADP
# that ADP
# those DET
# who NOUN
# are VERB
# caring VERB
# for ADP
# seriously ADV
# ill ADJ
# family NOUN
# members NOUN
# not ADV
# just ADV
# family NOUN
# members NOUN
# who NOUN
# are VERB
# at ADP
# risk NOUN
# of ADP
# death NOUN
# can VERB
# access VERB
# six NUM
# months NOUN
# of ADP
# benefits NOUN
# . PUNCT
# AFFORDABLE NOUN
# HOUSING NOUN
# We PRON
# will VERB
# make VERB
# it PRON
# easier ADJ
# for ADP
# Canadians PROPN
# to PART
# find VERB
# an DET
# affordable ADJ
# place NOUN
# to PART
# call VERB
# home ADV
# . PUNCT
# Today NOUN
# , PUNCT
# one NUM
# in ADP
# four NUM
# Canadian ADJ
# households NOUN
# is VERB
# paying VERB
# more ADJ
# than ADP
# it PRON
# can VERB
# afford VERB
# for ADP
# housing NOUN
# , PUNCT
# and CCONJ
# one NUM
# in ADP
# eight NUM
# can VERB
# not ADV
# find VERB
# affordable ADJ
# housing NOUN
# that ADJ
# is VERB
# safe ADJ
# , PUNCT
# suitable ADJ
# , PUNCT
# and CCONJ
# well ADV
# maintained VERB
# . PUNCT
# When ADV
# affordable ADJ
# housing NOUN
# is VERB
# in ADP
# short ADJ
# supply NOUN
# , PUNCT
# Canadians PROPN
# feel VERB
# less ADV
# secure ADJ
# and CCONJ
# our ADJ
# whole ADJ
# economy NOUN
# suffers VERB
# . PUNCT
# We PRON
# will VERB
# renew VERB
# federal ADJ
# leadership NOUN
# in ADP
# housing NOUN
# , PUNCT
# starting VERB
# with ADP
# a DET
# new ADJ
# , PUNCT
# ten NUM
# - PUNCT
# year NOUN
# investment NOUN
# in ADP
# social ADJ
# infrastructure NOUN
# . PUNCT
# We PRON
# will VERB
# prioritize VERB
# investments NOUN
# in ADP
# affordable ADJ
# housing NOUN
# and CCONJ
# seniors NOUN
# ' PART
# facilities NOUN
# , PUNCT
# build VERB
# more ADJ
# new ADJ
# housing NOUN
# units NOUN
# and CCONJ
# refurbish ADJ
# old ADJ
# ones NOUN
# , PUNCT
# give VERB
# support NOUN
# to ADP
# municipalities NOUN
# to PART
# maintain VERB
# rent NOUN
# - PUNCT
# geared VERB
# - PUNCT
# to ADP
# - PUNCT
# income NOUN
# subsidies NOUN
# in ADP
# co NOUN
# - PUNCT
# ops NOUN
# , PUNCT
# and CCONJ
# give VERB
# communities NOUN
# the DET
# money NOUN
# they PRON
# need VERB
# for ADP
# Housing PROPN
# First ADJ
# initiatives NOUN
# that ADJ
# help VERB
# homeless ADJ
# Canadians PROPN
# find VERB
# stable ADJ
# housing NOUN
# . PUNCT
# We PRON
# will VERB
# encourage VERB
# the DET
# construction NOUN
# of ADP
# new ADJ
# rental ADJ
# housing NOUN
# by ADP
# removing VERB
# all DET
# GST PROPN
# on ADP
# new ADJ
# capital NOUN
# investments NOUN
# in ADP
# affordable ADJ
# rental ADJ
# housing NOUN
# . PUNCT
# This DET
# will VERB
# provide VERB
# $ SYM
# 125 NUM
# million NUM
# per ADP
# year NOUN
# in ADP
# tax NOUN
# incentives NOUN
# to PART
# grow VERB
# and CCONJ
# renovate VERB
# the DET
# supply NOUN
# of ADP
# rental ADJ
# housing NOUN
# across ADP
# Canada PROPN
# . PUNCT
# We PRON
# will VERB
# modernize VERB
# the DET
# existing VERB
# Home PROPN
# Buyers PROPN
# ' PART
# Plan NOUN
# to PART
# allow VERB
# Canadians PROPN
# impacted VERB
# by ADP
# sudden ADJ
# and CCONJ
# significant ADJ
# life NOUN
# changes NOUN
# to PART
# buy VERB
# a DET
# house NOUN
# without ADP
# tax NOUN
# penalty NOUN
# . PUNCT
# This DET
# will VERB
# ease VERB
# the DET
# burden NOUN
# on ADP
# Canadians PROPN
# facing VERB
# job NOUN
# relocation NOUN
# , PUNCT
# the DET
# death NOUN
# of ADP
# a DET
# spouse NOUN
# , PUNCT
# marital ADJ
# breakdown NOUN
# , PUNCT
# or CCONJ
# a DET
# decision NOUN
# to PART
# accommodate VERB
# an DET
# elderly ADJ
# family NOUN
# member NOUN
# . PUNCT
# We PRON
# will VERB
# direct VERB
# the DET
# Canada PROPN
# Mortgage PROPN
# and CCONJ
# Housing PROPN
# Corporation PROPN
# and CCONJ
# the DET
# new ADJ
# Canada PROPN
# Infrastructure PROPN
# Bank PROPN
# to PART
# provide VERB
# financing NOUN
# to PART
# support VERB
# the DET
# construction NOUN
# of ADP
# new ADJ
# , PUNCT
# affordable ADJ
# rental ADJ
# housing NOUN
# for ADP
# middle- NOUN
# and CCONJ
# low ADJ
# - PUNCT
# income NOUN
# Canadians PROPN
# . PUNCT
# We PRON
# will VERB
# conduct VERB
# an DET
# inventory NOUN
# of ADP
# all DET
# available ADJ
# federal ADJ
# lands NOUN
# and CCONJ
# buildings NOUN
# that ADJ
# could VERB
# be VERB
# repurposed VERB
# , PUNCT
# and CCONJ
# make VERB
# some DET
# of ADP
# these DET
# lands NOUN
# available ADJ
# at ADP
# low ADJ
# cost NOUN
# for ADP
# affordable ADJ
# housing NOUN
# in ADP
# communities NOUN
# where ADV
# there ADV
# is VERB
# a DET
# pressing VERB
# need NOUN
# . PUNCT
# We PRON
# will VERB
# review VERB
# escalating VERB
# home NOUN
# prices NOUN
# in ADP
# high ADV
# - PUNCT
# priced VERB
# markets NOUN
# , PUNCT
# like ADP
# Toronto PROPN
# and CCONJ
# Vancouver PROPN
# , PUNCT
# and CCONJ
# consider VERB
# all DET
# policy NOUN
# tools NOUN
# that ADJ
# could VERB
# keep VERB
# home NOUN
# ownership NOUN
# within ADP
# reach NOUN
# for ADP
# more ADJ
# Canadians PROPN
# . PUNCT
# We PRON
# will VERB
# also ADV
# immediately ADV
# restore VERB
# the DET
# mandatory ADJ
# long ADJ
# - PUNCT
# form NOUN
# census NOUN
# to PART
# ensure VERB
# that ADP
# decisions NOUN
# on ADP
# housing NOUN
# are VERB
# made VERB
# using VERB
# the DET
# best ADJ
# and CCONJ
# most ADV
# up ADV
# - PUNCT
# to ADP
# - PUNCT
# date NOUN
# data NOUN
# available ADJ
# . PUNCT
# POST PROPN
# - PUNCT
# SECONDARY PROPN
# EDUCATION NOUN
# We PRON
# will VERB
# make VERB
# post NOUN
# - PUNCT
# secondary ADJ
# education NOUN
# more ADV
# affordable ADJ
# . PUNCT
# For ADP
# too ADV
# many ADJ
# Canadians PROPN
# , PUNCT
# rising VERB
# costs NOUN
# have VERB
# made VERB
# post NOUN
# - PUNCT
# secondary ADJ
# education NOUN
# increasingly ADV
# out ADP
# of ADP
# reach NOUN
# . PUNCT
# It PRON
# is VERB
# harder ADJ
# and CCONJ
# harder ADJ
# for ADP
# middle ADJ
# class NOUN
# families NOUN
# to PART
# save VERB
# for ADP
# their ADJ
# kids NOUN
# ' PART
# education NOUN
# , PUNCT
# while ADP
# many ADJ
# lower ADJ
# - PUNCT
# income NOUN
# families NOUN
# are VERB
# not ADV
# able ADJ
# to PART
# save VERB
# at ADV
# all ADV
# . PUNCT
# At ADP
# the DET
# same ADJ
# time NOUN
# , PUNCT
# the DET
# federal ADJ
# government NOUN
# spends VERB
# billions NOUN
# each DET
# year NOUN
# on ADP
# non ADJ
# - PUNCT
# refundable ADJ
# tax NOUN
# credits NOUN
# that ADJ
# offer VERB
# little ADJ
# direct ADJ
# help NOUN
# for ADP
# students NOUN
# when ADV
# they PRON
# need VERB
# it PRON
# . PUNCT
# We PRON
# will VERB
# provide VERB
# direct ADJ
# help NOUN
# to ADP
# students NOUN
# from ADP
# low- ADJ
# and CCONJ
# middle ADJ
# - PUNCT
# income NOUN
# families NOUN
# to PART
# help VERB
# them PRON
# pay VERB
# for ADP
# their ADJ
# education NOUN
# and CCONJ
# ensure VERB
# that ADP
# debt NOUN
# loads NOUN
# are VERB
# manageable ADJ
# . PUNCT
# We PRON
# will VERB
# increase VERB
# the DET
# maximum ADJ
# Canada PROPN
# Student PROPN
# Grant PROPN
# for ADP
# low ADJ
# - PUNCT
# income NOUN
# students NOUN
# to ADP
# $ SYM
# 3,000 NUM
# per ADP
# year NOUN
# for ADP
# full ADJ
# - PUNCT
# time NOUN
# students NOUN
# , PUNCT
# and CCONJ
# to ADP
# $ SYM
# 1,800 NUM
# per ADP
# year NOUN
# for ADP
# part ADJ
# - PUNCT
# time NOUN
# students NOUN
# . PUNCT
# In ADP
# addition NOUN
# , PUNCT
# to PART
# help VERB
# more ADJ
# students NOUN
# from ADP
# middle ADJ
# class NOUN
# families NOUN
# qualify VERB
# for ADP
# Canada PROPN
# Student PROPN
# Grants PROPN
# , PUNCT
# we PRON
# will VERB
# increase VERB
# the DET
# income NOUN
# thresholds NOUN
# for ADP
# eligibility NOUN
# , PUNCT
# giving VERB
# more ADJ
# Canadian ADJ
# students NOUN
# access VERB
# to ADP
# even ADV
# larger ADJ
# grants NOUN
# . PUNCT
# This DET
# investment NOUN
# will VERB
# be VERB
# funded VERB
# by ADP
# cancelling VERB
# the DET
# poorly ADV
# targeted VERB
# education NOUN
# and CCONJ
# textbook NOUN
# tax NOUN
# credits NOUN
# . PUNCT
# The DET
# tuition NOUN
# tax NOUN
# credit NOUN
# will VERB
# be VERB
# maintained VERB
# . PUNCT
# This DET
# will VERB
# increase VERB
# the DET
# level NOUN
# of ADP
# non ADJ
# - PUNCT
# repayable ADJ
# grant NOUN
# assistance NOUN
# to ADP
# students NOUN
# by ADP
# $ SYM
# 750 NUM
# million NUM
# per ADP
# year NOUN
# , PUNCT
# rising VERB
# to ADP
# $ SYM
# 850 NUM
# million NUM
# per ADP
# year NOUN
# by ADP
# 2019/20 NUM
# . PUNCT
# We PRON
# will VERB
# also ADV
# make VERB
# our ADJ
# student NOUN
# loan NOUN
# system NOUN
# more ADV
# flexible ADJ
# . PUNCT
# We PRON
# will VERB
# ensure VERB
# that ADP
# no DET
# graduate NOUN
# with ADP
# student NOUN
# loans NOUN
# will VERB
# be VERB
# required VERB
# to PART
# make VERB
# any DET
# repayment NOUN
# until ADP
# they PRON
# are VERB
# earning VERB
# an DET
# income NOUN
# of ADP
# at ADV
# least ADV
# $ SYM
# 25,000 NUM
# per ADP
# year NOUN
# . PUNCT
# This DET
# will VERB
# be VERB
# done VERB
# by ADP
# changing VERB
# the DET
# income NOUN
# thresholds NOUN
# in ADP
# the DET
# Repayment PROPN
# Assistance NOUN
# Plan PROPN
# for ADP
# recent ADJ
# graduates NOUN
# . PUNCT
# The DET
# federal ADJ
# government NOUN
# will VERB
# continue VERB
# to PART
# pay VERB
# the DET
# interest NOUN
# on ADP
# student NOUN
# loans NOUN
# until ADP
# graduates NOUN
# begin VERB
# to PART
# earn VERB
# sufficient ADJ
# incomes NOUN
# to PART
# take VERB
# over PART
# their ADJ
# own ADJ
# payments NOUN
# and CCONJ
# repay VERB
# their ADJ
# own ADJ
# loans NOUN
# . PUNCT
# We PRON
# will VERB
# work VERB
# with ADP
# provinces NOUN
# and CCONJ
# territories NOUN
# to PART
# ensure VERB
# that ADP
# they PRON
# do VERB
# not ADV
# assume VERB
# any DET
# additional ADJ
# costs NOUN
# , PUNCT
# and CCONJ
# to PART
# make VERB
# sure ADJ
# these DET
# investments NOUN
# go VERB
# directly ADV
# to ADP
# students NOUN
# . PUNCT
# Appropriate ADJ
# compensation NOUN
# will VERB
# be VERB
# offered VERB
# to ADP
# provinces NOUN
# and CCONJ
# territories NOUN
# that ADJ
# do VERB
# not ADV
# participate VERB
# in ADP
# the DET
# Canada PROPN
# Student PROPN
# Loan PROPN
# program NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# work VERB
# collaboratively ADV
# with ADP
# provinces NOUN
# and CCONJ
# territories NOUN
# to PART
# improve VERB
# promotion NOUN
# of ADP
# RESPs NOUN
# and CCONJ
# Canada PROPN
# Learning PROPN
# Bonds PROPN
# , PUNCT
# and CCONJ
# to PART
# make VERB
# registration NOUN
# simpler ADJ
# for ADP
# all DET
# families NOUN
# . PUNCT
# We PRON
# will VERB
# invest VERB
# $ SYM
# 50 NUM
# million NUM
# in ADP
# additional ADJ
# annual ADJ
# support NOUN
# to ADP
# the DET
# Post PROPN
# - PUNCT
# Secondary PROPN
# Student PROPN
# Support PROPN
# Program PROPN
# , PUNCT
# which ADJ
# supports VERB
# Indigenous ADJ
# students NOUN
# attending VERB
# post NOUN
# - PUNCT
# secondary ADJ
# education NOUN
# , PUNCT
# and CCONJ
# will VERB
# allow VERB
# the DET
# program NOUN
# to PART
# grow VERB
# in ADP
# line NOUN
# with ADP
# increasing VERB
# demand NOUN
# . PUNCT
# A DET
# NEW PROPN
# HEALTH PROPN
# ACCORD PROPN
# We PRON
# will VERB
# make VERB
# home NOUN
# care NOUN
# more ADV
# available ADJ
# , PUNCT
# prescription NOUN
# drugs NOUN
# more ADV
# affordable ADJ
# , PUNCT
# and CCONJ
# mental ADJ
# health NOUN
# care NOUN
# more ADV
# accessible ADJ
# . PUNCT
# Canada PROPN
# 's PART
# publicly ADV
# - PUNCT
# funded VERB
# universal ADJ
# health NOUN
# care NOUN
# system NOUN
# is VERB
# a DET
# source NOUN
# of ADP
# pride NOUN
# for ADP
# Canadians PROPN
# € SYM
# “ PUNCT
# and CCONJ
# a DET
# source NOUN
# of ADP
# economic ADJ
# security NOUN
# for ADP
# the DET
# middle ADJ
# class NOUN
# and CCONJ
# those DET
# working VERB
# hard ADV
# to PART
# join VERB
# it PRON
# . PUNCT
# When ADV
# Canadians PROPN
# are VERB
# in ADP
# good ADJ
# physical ADJ
# and CCONJ
# mental ADJ
# health NOUN
# , PUNCT
# they PRON
# are VERB
# able ADJ
# to PART
# work VERB
# better ADV
# , PUNCT
# be VERB
# more ADV
# productive ADJ
# , PUNCT
# and CCONJ
# contribute VERB
# more ADV
# fully ADV
# to ADP
# our ADJ
# economy NOUN
# while ADP
# living VERB
# healthier ADJ
# , PUNCT
# happier ADJ
# lives NOUN
# . PUNCT
# Despite ADP
# our ADJ
# health NOUN
# care NOUN
# system NOUN
# 's PART
# value NOUN
# and CCONJ
# importance NOUN
# , PUNCT
# it PRON
# has VERB
# been VERB
# more ADJ
# than ADP
# a DET
# decade NOUN
# since ADP
# a DET
# Canadian ADJ
# Prime PROPN
# Minister PROPN
# sat VERB
# down PART
# with ADP
# provincial ADJ
# and CCONJ
# territorial ADJ
# Premiers PROPN
# to PART
# strengthen VERB
# the DET
# program NOUN
# , PUNCT
# and CCONJ
# ensure VERB
# that ADP
# it PRON
# can VERB
# meet VERB
# current ADJ
# needs NOUN
# and CCONJ
# the DET
# challenges NOUN
# that ADJ
# come VERB
# with ADP
# an DET
# aging VERB
# population NOUN
# . PUNCT
# We PRON
# will VERB
# restart VERB
# that ADP
# important ADJ
# conversation NOUN
# and CCONJ
# provide VERB
# the DET
# collaborative ADJ
# federal ADJ
# leadership NOUN
# that ADJ
# has VERB
# been VERB
# missing VERB
# during ADP
# the DET
# Harper PROPN
# decade NOUN
# . PUNCT
# We PRON
# will VERB
# negotiate VERB
# a DET
# new ADJ
# Health PROPN
# Accord PROPN
# with ADP
# provinces NOUN
# and CCONJ
# territories NOUN
# , PUNCT
# including VERB
# a DET
# long ADJ
# - PUNCT
# term NOUN
# agreement NOUN
# on ADP
# funding NOUN
# . PUNCT
# As ADP
# an DET
# immediate ADJ
# commitment NOUN
# , PUNCT
# we PRON
# will VERB
# invest VERB
# $ SYM
# 3 NUM
# billion NUM
# , PUNCT
# over ADP
# the DET
# next ADJ
# four NUM
# years NOUN
# , PUNCT
# to PART
# deliver VERB
# more ADJ
# and CCONJ
# better ADJ
# home NOUN
# care NOUN
# services NOUN
# for ADP
# all DET
# Canadians PROPN
# . PUNCT
# This DET
# includes VERB
# more ADJ
# access NOUN
# to ADP
# high ADJ
# quality NOUN
# in ADP
# - PUNCT
# home NOUN
# caregivers NOUN
# , PUNCT
# financial ADJ
# supports NOUN
# for ADP
# family NOUN
# care NOUN
# , PUNCT
# and CCONJ
# , PUNCT
# when ADV
# necessary ADJ
# , PUNCT
# palliative ADJ
# care NOUN
# . PUNCT
# To PART
# help VERB
# families NOUN
# care VERB
# for ADP
# their ADJ
# loved VERB
# ones NOUN
# at ADP
# home NOUN
# , PUNCT
# we PRON
# will VERB
# make VERB
# the DET
# Employment PROPN
# Insurance PROPN
# Compassionate PROPN
# Care PROPN
# Benefit PROPN
# more ADV
# flexible ADJ
# and CCONJ
# easier ADJ
# to PART
# access VERB
# , PUNCT
# so ADP
# that ADP
# it PRON
# provides VERB
# help NOUN
# for ADP
# more ADJ
# than ADP
# just ADV
# end NOUN
# - PUNCT
# of ADP
# - PUNCT
# life NOUN
# care NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# develop VERB
# a DET
# pan NOUN
# - PUNCT
# Canadian ADJ
# collaboration NOUN
# on ADP
# health NOUN
# innovation NOUN
# , PUNCT
# and CCONJ
# will VERB
# improve VERB
# access NOUN
# to ADP
# necessary ADJ
# prescription NOUN
# medications NOUN
# . PUNCT
# We PRON
# will VERB
# join VERB
# with ADP
# provincial ADJ
# and CCONJ
# territorial ADJ
# governments NOUN
# to PART
# buy VERB
# drugs NOUN
# in ADP
# bulk NOUN
# , PUNCT
# reducing VERB
# the DET
# cost NOUN
# Canadian ADJ
# governments NOUN
# pay VERB
# for ADP
# these DET
# drugs NOUN
# , PUNCT
# and CCONJ
# making VERB
# them PRON
# more ADV
# affordable ADJ
# for ADP
# Canadians PROPN
# . PUNCT
# We PRON
# will VERB
# make VERB
# high ADJ
# - PUNCT
# quality NOUN
# mental ADJ
# health NOUN
# services NOUN
# more ADV
# available ADJ
# to ADP
# Canadians PROPN
# who NOUN
# need VERB
# them PRON
# , PUNCT
# including VERB
# our ADJ
# veterans NOUN
# and CCONJ
# first ADJ
# responders NOUN
# . PUNCT
# To PART
# eliminate VERB
# systemic ADJ
# barriers NOUN
# and CCONJ
# deliver VERB
# equality NOUN
# of ADP
# opportunity NOUN
# to ADP
# all DET
# Canadians PROPN
# living VERB
# with ADP
# disabilities NOUN
# , PUNCT
# we PRON
# will VERB
# consult VERB
# with ADP
# provinces NOUN
# , PUNCT
# territories NOUN
# , PUNCT
# and CCONJ
# other ADJ
# stakeholders NOUN
# to PART
# introduce VERB
# a DET
# National PROPN
# Disabilities PROPN
# Act PROPN
# . PUNCT
# FIGHTING VERB
# POVERTY NOUN
# We PRON
# will VERB
# also ADV
# lift VERB
# more ADJ
# Canadians PROPN
# including VERB
# children NOUN
# and CCONJ
# seniors NOUN
# out ADP
# of ADP
# poverty NOUN
# . PUNCT
# Poverty NOUN
# and CCONJ
# inequality NOUN
# are VERB
# not ADV
# just ADV
# problems NOUN
# for ADP
# individual ADJ
# Canadians PROPN
# all DET
# of ADP
# Canada PROPN
# is VERB
# affected VERB
# . PUNCT
# For ADP
# Canadians PROPN
# , PUNCT
# poverty NOUN
# makes VERB
# it PRON
# more ADV
# difficult ADJ
# to PART
# get VERB
# and CCONJ
# stay VERB
# healthy ADJ
# , PUNCT
# and CCONJ
# more ADV
# difficult ADJ
# to PART
# find VERB
# and CCONJ
# keep VERB
# good ADJ
# work NOUN
# . PUNCT
# For ADP
# Canada PROPN
# , PUNCT
# the DET
# costs NOUN
# of ADP
# poverty NOUN
# seen VERB
# in ADP
# higher ADJ
# health NOUN
# care NOUN
# costs NOUN
# and CCONJ
# greater ADJ
# demand NOUN
# for ADP
# social ADJ
# assistance NOUN
# are VERB
# immense ADJ
# . PUNCT
# Our ADJ
# plan NOUN
# will VERB
# lift VERB
# Canadians PROPN
# out ADP
# of ADP
# poverty NOUN
# starting VERB
# immediately ADV
# after ADP
# the DET
# next ADJ
# election NOUN
# . PUNCT
# We PRON
# will VERB
# introduce VERB
# a DET
# new ADJ
# Canada PROPN
# Child PROPN
# Benefit PROPN
# . PUNCT
# Tax NOUN
# - PUNCT
# free ADJ
# , PUNCT
# tied VERB
# to ADP
# income NOUN
# and CCONJ
# delivered VERB
# monthly ADV
# , PUNCT
# this DET
# benefit NOUN
# provides VERB
# greater ADJ
# support NOUN
# to ADP
# those DET
# who NOUN
# need VERB
# help NOUN
# most ADV
# : PUNCT
# single ADJ
# - PUNCT
# parent NOUN
# families NOUN
# and CCONJ
# low ADJ
# - PUNCT
# income NOUN
# families NOUN
# . PUNCT
# It PRON
# will VERB
# lift VERB
# 315,000 NUM
# children NOUN
# out ADP
# of ADP
# poverty NOUN
# . PUNCT
# We PRON
# will VERB
# help VERB
# to PART
# lift VERB
# hundreds NOUN
# of ADP
# thousands NOUN
# of ADP
# seniors NOUN
# out ADP
# of ADP
# poverty NOUN
# by ADP
# increasing VERB
# the DET
# Guaranteed PROPN
# Income PROPN
# Supplement PROPN
# for ADP
# single ADJ
# low ADJ
# - PUNCT
# income NOUN
# seniors NOUN
# by ADP
# ten NUM
# percent NOUN
# . PUNCT
# This DET
# will VERB
# give VERB
# one NUM
# million NUM
# of ADP
# our ADJ
# most ADV
# vulnerable ADJ
# seniors NOUN
# who NOUN
# are VERB
# often ADV
# women NOUN
# almost ADV
# $ SYM
# 1,000 NUM
# more ADJ
# each DET
# year NOUN
# . PUNCT
# And CCONJ
# , PUNCT
# as ADP
# part NOUN
# of ADP
# our ADJ
# new ADJ
# investment NOUN
# in ADP
# social ADJ
# infrastructure NOUN
# , PUNCT
# we PRON
# will VERB
# prioritize VERB
# investments NOUN
# in ADP
# affordable ADJ
# housing NOUN
# and CCONJ
# seniors NOUN
# ' PART
# facilities NOUN
# , PUNCT
# build VERB
# more ADJ
# new ADJ
# housing NOUN
# units NOUN
# and CCONJ
# refurbish ADJ
# old ADJ
# ones NOUN
# , PUNCT
# give VERB
# support NOUN
# to ADP
# municipalities NOUN
# to PART
# maintain VERB
# rent NOUN
# - PUNCT
# geared VERB
# - PUNCT
# to ADP
# - PUNCT
# income NOUN
# subsidies NOUN
# in ADP
# co NOUN
# - PUNCT
# ops NOUN
# , PUNCT
# and CCONJ
# give VERB
# communities NOUN
# the DET
# money NOUN
# they PRON
# need VERB
# for ADP
# Housing PROPN
# First ADJ
# initiatives NOUN
# that ADJ
# help VERB
# homeless ADJ
# Canadians PROPN
# find VERB
# stable ADJ
# housing NOUN
# . PUNCT
# INVESTING VERB
# TO PART
# STRENGTHEN VERB
# THE DET
# MIDDLE ADJ
# CLASS NOUN
# Under ADP
# Stephen PROPN
# Harper PROPN
# , PUNCT
# Canada PROPN
# 's PART
# economy NOUN
# has VERB
# faltered VERB
# , PUNCT
# and CCONJ
# our ADJ
# middle ADJ
# class NOUN
# now ADV
# finds VERB
# it PRON
# harder ADV
# and CCONJ
# harder ADV
# to PART
# make VERB
# ends NOUN
# meet VERB
# It PRON
# is VERB
# time NOUN
# for ADP
# smart ADJ
# , PUNCT
# strategic ADJ
# investments NOUN
# that ADJ
# will VERB
# turn VERB
# our ADJ
# economy NOUN
# around ADV
# and CCONJ
# get VERB
# it PRON
# growing VERB
# again ADV
# . PUNCT
# Our ADJ
# plan NOUN
# will VERB
# deliver VERB
# the DET
# services NOUN
# we PRON
# need VERB
# , PUNCT
# create VERB
# jobs NOUN
# , PUNCT
# and CCONJ
# restore VERB
# economic ADJ
# security NOUN
# to ADP
# the DET
# middle ADJ
# class NOUN
# . PUNCT
# We PRON
# will VERB
# invest VERB
# now ADV
# in ADP
# the DET
# projects NOUN
# our ADJ
# country NOUN
# needs VERB
# and CCONJ
# the DET
# people NOUN
# who NOUN
# can VERB
# build VERB
# them PRON
# . PUNCT
# Interest NOUN
# rates NOUN
# are VERB
# at ADP
# historic ADJ
# lows NOUN
# , PUNCT
# our ADJ
# current ADJ
# infrastructure NOUN
# is VERB
# aging VERB
# rapidly ADV
# , PUNCT
# and CCONJ
# our ADJ
# economy NOUN
# is VERB
# stuck VERB
# in ADP
# neutral ADJ
# . PUNCT
# Now ADV
# is VERB
# the DET
# time NOUN
# to PART
# invest VERB
# . PUNCT
# We PRON
# will VERB
# run VERB
# modest ADJ
# short ADJ
# - PUNCT
# term NOUN
# deficits NOUN
# of ADP
# less ADJ
# than ADP
# $ SYM
# 10 NUM
# billion NUM
# in ADP
# each DET
# of ADP
# the DET
# next ADJ
# two NUM
# fiscal ADJ
# years NOUN
# to PART
# fund VERB
# historic ADJ
# investments NOUN
# in ADP
# infrastructure NOUN
# and CCONJ
# our ADJ
# middle ADJ
# class NOUN
# . PUNCT
# After ADP
# the DET
# next ADJ
# two NUM
# fiscal ADJ
# years NOUN
# , PUNCT
# the DET
# deficit NOUN
# will VERB
# decline VERB
# and CCONJ
# our ADJ
# investment NOUN
# plan NOUN
# will VERB
# return VERB
# Canada PROPN
# to ADP
# a DET
# balanced ADJ
# budget NOUN
# in ADP
# 2019 NUM
# . PUNCT
# PUBLIC ADJ
# TRANSIT NOUN
# We PRON
# will VERB
# invest VERB
# in ADP
# public ADJ
# transit NOUN
# to PART
# shorten VERB
# commute NOUN
# times NOUN
# , PUNCT
# cut VERB
# air NOUN
# pollution NOUN
# , PUNCT
# strengthen VERB
# our ADJ
# communities NOUN
# , PUNCT
# and CCONJ
# grow VERB
# our ADJ
# economy NOUN
# . PUNCT
# Canadian ADJ
# cities NOUN
# have VERB
# been VERB
# growing VERB
# at ADP
# a DET
# rapid ADJ
# rate NOUN
# , PUNCT
# but CCONJ
# investment NOUN
# in ADP
# public ADJ
# transit NOUN
# has VERB
# not ADV
# kept VERB
# pace NOUN
# . PUNCT
# Stephen PROPN
# Harper PROPN
# 's PART
# failure NOUN
# to PART
# invest VERB
# has VERB
# led VERB
# to ADP
# worsening VERB
# traffic NOUN
# congestion NOUN
# , PUNCT
# making VERB
# it PRON
# harder ADV
# for ADP
# families NOUN
# to PART
# spend VERB
# time NOUN
# together ADV
# This DET
# gridlock NOUN
# also ADV
# costs VERB
# our ADJ
# economy NOUN
# billions NOUN
# of ADP
# dollars NOUN
# in ADP
# lost ADJ
# productivity NOUN
# each DET
# year NOUN
# . PUNCT
# We PRON
# will VERB
# get VERB
# our ADJ
# communities NOUN
# moving VERB
# again ADV
# , PUNCT
# by ADP
# giving VERB
# our ADJ
# provinces NOUN
# , PUNCT
# territories NOUN
# , PUNCT
# and CCONJ
# municipalities VERB
# the DET
# long ADJ
# - PUNCT
# term NOUN
# , PUNCT
# predictable ADJ
# federal ADJ
# funding NOUN
# they PRON
# need VERB
# to PART
# make VERB
# transit NOUN
# plans NOUN
# a DET
# reality NOUN
# . PUNCT
# Over ADP
# the DET
# next ADJ
# decade NOUN
# , PUNCT
# we PRON
# will VERB
# quadruple VERB
# federal ADJ
# investment NOUN
# in ADP
# public ADJ
# transit NOUN
# , PUNCT
# investing VERB
# almost ADV
# $ SYM
# 20 NUM
# billion NUM
# more ADJ
# in ADP
# transit NOUN
# infrastructure NOUN
# . PUNCT
# In ADP
# communities NOUN
# all ADV
# across ADP
# Canada PROPN
# , PUNCT
# transit NOUN
# projects NOUN
# are VERB
# ready ADJ
# to PART
# go VERB
# . PUNCT
# In ADP
# British PROPN
# Columbia PROPN
# 's PART
# Lower ADJ
# Mainland PROPN
# , PUNCT
# for ADP
# example NOUN
# , PUNCT
# plans NOUN
# are VERB
# in ADP
# place NOUN
# to ADP
# : PUNCT
#   SPACE
# € PUNCT
# ¢ ADJ
# increase NOUN
# SeaBus PROPN
# service NOUN
# to ADP
# every DET
# ten NUM
# minutes NOUN
# during ADP
# morning NOUN
# and CCONJ
# afternoon NOUN
# rushes VERB
# ; PUNCT
# extend VERB
# rapid ADJ
# transit NOUN
# service NOUN
# along ADP
# Broadway PROPN
# , PUNCT
# currently ADV
# the DET
# busiest ADJ
# bus NOUN
# corridor NOUN
# in ADP
# North PROPN
# America PROPN
# ; PUNCT
# and CCONJ
#   SPACE
# € PUNCT
# ¢ ADJ
# bring VERB
# light ADJ
# rail NOUN
# transit NOUN
# to ADP
# Surrey PROPN
# , PUNCT
# one NUM
# of ADP
# the DET
# fastest ADJ
# growing VERB
# parts NOUN
# of ADP
# the DET
# region NOUN
# . PUNCT
# We PRON
# will VERB
# work VERB
# with ADP
# provinces NOUN
# and CCONJ
# municipalities NOUN
# across ADP
# the DET
# country NOUN
# to PART
# get VERB
# projects NOUN
# like ADP
# these DET
# done VERB
# . PUNCT
# STRONGER ADJ
# COMMUNITIES NOUN
# We PRON
# will VERB
# strengthen VERB
# our ADJ
# communities NOUN
# by ADP
# investing VERB
# in ADP
# the DET
# things NOUN
# that ADJ
# make VERB
# them PRON
# good ADJ
# places NOUN
# to PART
# live VERB
# . PUNCT
# Investing VERB
# in ADP
# our ADJ
# communities NOUN
# is VERB
# not ADV
# just ADV
# about ADP
# creating VERB
# good ADJ
# jobs NOUN
# and CCONJ
# economic ADJ
# growth NOUN
# . PUNCT
# It PRON
# is VERB
# also ADV
# about ADP
# building NOUN
# communities NOUN
# that ADJ
# we PRON
# are VERB
# proud ADJ
# to PART
# call VERB
# home ADV
# . PUNCT
# With ADP
# historic ADJ
# new ADJ
# investments NOUN
# in ADP
# social ADJ
# infrastructure NOUN
# , PUNCT
# we PRON
# will VERB
# achieve VERB
# both DET
# . PUNCT
# We PRON
# will VERB
# improve VERB
# quality NOUN
# of ADP
# life NOUN
# for ADP
# millions NOUN
# of ADP
# Canadians PROPN
# by ADP
# prioritizing VERB
# investment NOUN
# in ADP
# affordable ADJ
# housing NOUN
# , PUNCT
# seniors NOUN
# ' PART
# facilities NOUN
# , PUNCT
# early ADJ
# learning NOUN
# and CCONJ
# child NOUN
# care NOUN
# , PUNCT
# and CCONJ
# cultural ADJ
# and CCONJ
# recreational ADJ
# infrastructure NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# work VERB
# with ADP
# provinces NOUN
# , PUNCT
# territories NOUN
# , PUNCT
# and CCONJ
# First PROPN
# Nations PROPN
# to PART
# create VERB
# a DET
# new ADJ
# National PROPN
# Early PROPN
# Learning PROPN
# and CCONJ
# Child PROPN
# Care PROPN
# Framework PROPN
# , PUNCT
# to PART
# ensure VERB
# that ADP
# affordable ADJ
# , PUNCT
# high ADJ
# - PUNCT
# quality NOUN
# , PUNCT
# fully ADV
# inclusive ADJ
# child NOUN
# care NOUN
# is VERB
# available ADJ
# to ADP
# all DET
# families NOUN
# who NOUN
# need VERB
# it PRON
# . PUNCT
# Over ADP
# the DET
# next ADJ
# decade NOUN
# , PUNCT
# we PRON
# will VERB
# invest VERB
# almost ADV
# $ SYM
# 20 NUM
# billion NUM
# more ADJ
# in ADP
# Canada PROPN
# 's PART
# social ADJ
# infrastructure NOUN
# . PUNCT
# Toronto PROPN
# 's PART
# Alexandra PROPN
# Park PROPN
# is VERB
# an DET
# example NOUN
# of ADP
# an DET
# urban ADJ
# community NOUN
# where ADV
# investments NOUN
# in ADP
# social ADJ
# infrastructure NOUN
# are VERB
# already ADV
# building VERB
# a DET
# brighter ADJ
# future NOUN
# for ADP
# its ADJ
# residents NOUN
# . PUNCT
# Aging VERB
# community NOUN
# housing NOUN
# is VERB
# being VERB
# replaced VERB
# with ADP
# new ADJ
# affordable ADJ
# housing NOUN
# , PUNCT
# new ADJ
# commercial ADJ
# spaces NOUN
# , PUNCT
# and CCONJ
# new ADJ
# parkland NOUN
# € SYM
# “ PUNCT
# all DET
# helping VERB
# to PART
# grow VERB
# this DET
# vibrant ADJ
# neighbourhood NOUN
# and CCONJ
# improve VERB
# the DET
# quality NOUN
# of ADP
# life NOUN
# for ADP
# all DET
# who NOUN
# call VERB
# it PRON
# home ADV
# . PUNCT
# " PUNCT
# With ADP
# a DET
# federal ADJ
# partner NOUN
# at ADP
# the DET
# table NOUN
# , PUNCT
# stories NOUN
# like ADP
# the DET
# revitalization NOUN
# of ADP
# Alexandra PROPN
# Park PROPN
# can VERB
# happen VERB
# in ADP
# communities NOUN
# all ADV
# across ADP
# Canada PROPN
# . PUNCT
# GREENER PROPN
# COMMUNITIES PROPN
# We PRON
# will VERB
# invest VERB
# in ADP
# sustainable ADJ
# infrastructure NOUN
# that ADJ
# makes VERB
# our ADJ
# communities NOUN
# safer ADJ
# and CCONJ
# more ADV
# resilient ADJ
# . PUNCT
# Responsible ADJ
# governments NOUN
# do VERB
# not ADV
# walk VERB
# away ADV
# from ADP
# challenges NOUN
# , PUNCT
# or CCONJ
# pretend VERB
# they PRON
# do VERB
# not ADV
# exist VERB
# . PUNCT
# We PRON
# will VERB
# protect VERB
# our ADJ
# communities NOUN
# from ADP
# the DET
# challenges NOUN
# of ADP
# climate NOUN
# change NOUN
# and CCONJ
# grow VERB
# our ADJ
# economy NOUN
# by ADP
# making VERB
# significant ADJ
# new ADJ
# investments NOUN
# in ADP
# green ADJ
# infrastructure NOUN
# . PUNCT
# This DET
# includes VERB
# investments NOUN
# in ADP
# local ADJ
# water NOUN
# and CCONJ
# wastewater NOUN
# facilities NOUN
# ; PUNCT
# clean ADJ
# energy NOUN
# ; PUNCT
# climate NOUN
# resilient ADJ
# infrastructure NOUN
# , PUNCT
# including VERB
# flood NOUN
# mitigation NOUN
# systems NOUN
# ; PUNCT
# and CCONJ
# infrastructure NOUN
# to PART
# protect VERB
# against ADP
# changing VERB
# weather NOUN
# . PUNCT
# We PRON
# will VERB
# boost VERB
# investment NOUN
# in ADP
# green ADJ
# infrastructure NOUN
# by ADP
# nearly ADV
# $ SYM
# 6 NUM
# billion NUM
# over ADP
# the DET
# next ADJ
# four NUM
# years NOUN
# , PUNCT
# and CCONJ
# almost ADV
# $ SYM
# 20 NUM
# billion NUM
# over ADP
# ten NUM
# years NOUN
# . PUNCT
# When ADV
# it PRON
# comes VERB
# to ADP
# infrastructure NOUN
# that ADJ
# will VERB
# help VERB
# keep VERB
# Canadians PROPN
# safe ADJ
# and CCONJ
# better ADV
# prepared VERB
# for ADP
# emergencies NOUN
# , PUNCT
# local ADJ
# leaders NOUN
# know VERB
# what NOUN
# needs VERB
# to PART
# be VERB
# done VERB
# . PUNCT
# What NOUN
# they PRON
# need VERB
# is VERB
# a DET
# federal ADJ
# partner NOUN
# willing ADJ
# to PART
# invest VERB
# to PART
# help VERB
# build VERB
# stronger ADJ
# , PUNCT
# more ADV
# resilient ADJ
# communities NOUN
# . PUNCT
# In ADP
# St. PROPN
# John PROPN
# 's PART
# , PUNCT
# this DET
# means VERB
# upgrades NOUN
# to ADP
# its ADJ
# wastewater NOUN
# plant NOUN
# . PUNCT
# In ADP
# Trois PROPN
# - PUNCT
# Rivi¨res NOUN
# , PUNCT
# this DET
# means VERB
# improving VERB
# the DET
# Maples PROPN
# and CCONJ
# Cardinal PROPN
# - PUNCT
# Roy PROPN
# reservoirs NOUN
# , PUNCT
# and CCONJ
# finding VERB
# ways NOUN
# to PART
# mitigate VERB
# the DET
# regular ADJ
# flooding NOUN
# of ADP
# the DET
# Millette PROPN
# , PUNCT
# Bettez PROPN
# , PUNCT
# and CCONJ
# Lacerte PROPN
# rivers NOUN
# . PUNCT
# In ADP
# Calgary PROPN
# and CCONJ
# Southern PROPN
# Alberta PROPN
# , PUNCT
# this DET
# means VERB
# investments NOUN
# in ADP
# flood NOUN
# mitigation NOUN
# projects NOUN
# , PUNCT
# to PART
# help VERB
# protect VERB
# local ADJ
# families NOUN
# and CCONJ
# businesses NOUN
# . PUNCT
# NEW ADJ
# BUILDING PROPN
# CANADA PROPN
# FUND PROPN
# We PRON
# will VERB
# make VERB
# the DET
# New PROPN
# Building PROPN
# Canada PROPN
# Fund PROPN
# more ADV
# focused VERB
# and CCONJ
# more ADV
# transparent ADJ
# . PUNCT
# The DET
# New PROPN
# Building PROPN
# Canada PROPN
# Fund PROPN
# is VERB
# an DET
# important ADJ
# source NOUN
# of ADP
# infrastructure NOUN
# funding NOUN
# for ADP
# Canadian ADJ
# communities NOUN
# , PUNCT
# but CCONJ
# it PRON
# has VERB
# been VERB
# hit VERB
# by ADP
# dramatic ADJ
# cuts NOUN
# and CCONJ
# is VERB
# heavily ADV
# back ADV
# - PUNCT
# loaded VERB
# , PUNCT
# with ADP
# more ADJ
# than ADP
# 70 NUM
# percent NOUN
# of ADP
# its ADJ
# funding NOUN
# locked VERB
# away ADV
# until ADP
# after ADP
# 2019 NUM
# . PUNCT
# We PRON
# will VERB
# make VERB
# the DET
# New PROPN
# Building PROPN
# Canada PROPN
# Fund PROPN
# more ADV
# focused ADJ
# . PUNCT
# By ADP
# providing VERB
# significant ADJ
# , PUNCT
# separate ADJ
# investments NOUN
# in ADP
# public ADJ
# transit NOUN
# , PUNCT
# social ADJ
# infrastructure NOUN
# , PUNCT
# and CCONJ
# green ADJ
# infrastructure NOUN
# , PUNCT
# we PRON
# will VERB
# enable VERB
# the DET
# New PROPN
# Building PROPN
# Canada PROPN
# Fund PROPN
# to PART
# make VERB
# greater ADJ
# investments NOUN
# in ADP
# Canada PROPN
# 's PART
# roads NOUN
# , PUNCT
# bridges NOUN
# , PUNCT
# transportation NOUN
# corridors NOUN
# , PUNCT
# ports NOUN
# , PUNCT
# and CCONJ
# border NOUN
# gateways NOUN
# , PUNCT
# helping VERB
# Canada PROPN
# 's PART
# manufacturers NOUN
# get VERB
# their ADJ
# goods NOUN
# to ADP
# market NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# make VERB
# the DET
# fund NOUN
# more ADV
# transparent ADJ
# , PUNCT
# by ADP
# providing VERB
# clearer ADJ
# project NOUN
# criteria NOUN
# , PUNCT
# along ADP
# with ADP
# faster ADJ
# approval NOUN
# processes NOUN
# . PUNCT
# KEEPING VERB
# OUR ADJ
# COMMITMENT NOUN
# TO ADP
# COMMUNITIES NOUN
# We PRON
# will VERB
# make VERB
# sure ADJ
# that ADP
# no DET
# money NOUN
# intended VERB
# for ADP
# investment NOUN
# in ADP
# communities NOUN
# is VERB
# allowed VERB
# to PART
# lapse VERB
# . PUNCT
# Too ADV
# often ADV
# , PUNCT
# Stephen PROPN
# Harper PROPN
# budgeted VERB
# funds NOUN
# for ADP
# use NOUN
# in ADP
# our ADJ
# communities NOUN
# , PUNCT
# then ADV
# let VERB
# those DET
# dollars NOUN
# go VERB
# unspent ADJ
# . PUNCT
# We PRON
# will VERB
# make VERB
# sure ADJ
# our ADJ
# communities NOUN
# are VERB
# not ADV
# shortchanged VERB
# . PUNCT
# Near ADP
# the DET
# end NOUN
# of ADP
# the DET
# fiscal ADJ
# year NOUN
# , PUNCT
# we PRON
# will VERB
# automatically ADV
# transfer VERB
# any DET
# uncommitted ADJ
# federal ADJ
# infrastructure NOUN
# funds NOUN
# to ADP
# municipalities NOUN
# , PUNCT
# through ADP
# a DET
# temporary ADJ
# top NOUN
# - PUNCT
# up NOUN
# of ADP
# the DET
# Gas PROPN
# Tax PROPN
# Fund PROPN
# . PUNCT
# This DET
# will VERB
# ensure VERB
# that ADP
# no DET
# committed ADJ
# infrastructure NOUN
# money NOUN
# is VERB
# allowed VERB
# to PART
# lapse VERB
# , PUNCT
# but CCONJ
# is VERB
# instead ADV
# always ADV
# invested VERB
# in ADP
# our ADJ
# communities NOUN
# . PUNCT
# CANADA PROPN
# INFRASTRUCTURE PROPN
# BANK PROPN
# We PRON
# will VERB
# establish VERB
# the DET
# Canadian ADJ
# Infrastructure PROPN
# Bank PROPN
# to PART
# provide VERB
# low ADJ
# - PUNCT
# cost NOUN
# financing NOUN
# for ADP
# new ADJ
# infrastructure NOUN
# projects NOUN
# . PUNCT
# The DET
# federal ADJ
# government NOUN
# can VERB
# use VERB
# its ADJ
# strong ADJ
# credit NOUN
# rating NOUN
# and CCONJ
# lending NOUN
# authority NOUN
# to PART
# make VERB
# it PRON
# easier ADJ
# and CCONJ
# more ADV
# affordable ADJ
# for ADP
# municipalities NOUN
# to PART
# build VERB
# the DET
# projects NOUN
# their ADJ
# communities NOUN
# need VERB
# . PUNCT
# Where ADV
# a DET
# lack NOUN
# of ADP
# capital NOUN
# represents VERB
# a DET
# barrier NOUN
# to ADP
# projects NOUN
# , PUNCT
# the DET
# Canada PROPN
# Infrastructure PROPN
# Bank PROPN
# will VERB
# provide VERB
# loan NOUN
# guarantees NOUN
# and CCONJ
# small ADJ
# capital NOUN
# contributions NOUN
# to ADP
# provinces NOUN
# and CCONJ
# municipalities NOUN
# to PART
# ensure VERB
# that ADP
# the DET
# projects NOUN
# are VERB
# built VERB
# . PUNCT
# JOB PROPN
# AND CCONJ
# SKILLS PROPN
# TRAINING NOUN
# We PRON
# will VERB
# help VERB
# Canadians PROPN
# get VERB
# the DET
# training NOUN
# they PRON
# need VERB
# to PART
# find VERB
# and CCONJ
# keep VERB
# good ADJ
# jobs NOUN
# . PUNCT
# In ADP
# a DET
# changing VERB
# economy NOUN
# , PUNCT
# Canadians PROPN
# need VERB
# more ADJ
# opportunities NOUN
# to PART
# improve VERB
# their ADJ
# skills NOUN
# and CCONJ
# upgrade VERB
# their ADJ
# credentials NOUN
# . PUNCT
# We PRON
# will VERB
# make VERB
# it PRON
# easier ADJ
# for ADP
# adults NOUN
# to PART
# access VERB
# training NOUN
# programs NOUN
# by ADP
# increasing VERB
# investment NOUN
# in ADP
# skills NOUN
# training NOUN
# . PUNCT
# To PART
# help VERB
# those DET
# receiving VERB
# Employment PROPN
# Insurance PROPN
# get VERB
# the DET
# training NOUN
# they PRON
# need VERB
# to PART
# rejoin VERB
# the DET
# workforce NOUN
# , PUNCT
# we PRON
# will VERB
# invest VERB
# $ SYM
# 500 NUM
# million NUM
# more ADJ
# each DET
# year NOUN
# in ADP
# provincial ADJ
# and CCONJ
# territorial ADJ
# Labour PROPN
# Market PROPN
# Development PROPN
# Agreements PROPN
# . PUNCT
# To PART
# help VERB
# those DET
# who NOUN
# do VERB
# not ADV
# qualify VERB
# for ADP
# Employment PROPN
# Insurance PROPN
# or CCONJ
# are VERB
# not ADV
# currently ADV
# employed VERB
# , PUNCT
# we PRON
# will VERB
# invest VERB
# an DET
# additional ADJ
# $ SYM
# 200 NUM
# million NUM
# in ADP
# training NOUN
# programs NOUN
# led VERB
# by ADP
# the DET
# provinces NOUN
# and CCONJ
# territories NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# invest VERB
# $ SYM
# 50 NUM
# million NUM
# to PART
# renew VERB
# and CCONJ
# expand VERB
# funding NOUN
# to ADP
# the DET
# Aboriginal PROPN
# Skills PROPN
# and CCONJ
# Employment PROPN
# Training PROPN
# Strategy PROPN
# , PUNCT
# and CCONJ
# provide VERB
# $ SYM
# 25 NUM
# million NUM
# each DET
# year NOUN
# for ADP
# training NOUN
# facilities NOUN
# , PUNCT
# delivered VERB
# in ADP
# partnership NOUN
# with ADP
# labour ADJ
# unions NOUN
# . PUNCT
# We PRON
# will VERB
# work VERB
# with ADP
# employers NOUN
# and CCONJ
# workers NOUN
# to PART
# determine VERB
# an DET
# appropriate ADJ
# apprenticeship NOUN
# ratio NOUN
# for ADP
# all DET
# federal ADJ
# infrastructure NOUN
# projects NOUN
# . PUNCT
# Our ADJ
# total ADJ
# investment NOUN
# of ADP
# an DET
# additional ADJ
# $ SYM
# 775 NUM
# million NUM
# per ADP
# year NOUN
# for ADP
# job NOUN
# and CCONJ
# skills NOUN
# training NOUN
# will VERB
# help VERB
# Canadians PROPN
# get VERB
# the DET
# training NOUN
# they PRON
# need VERB
# to PART
# find VERB
# and CCONJ
# keep VERB
# good ADJ
# jobs NOUN
# . PUNCT
# JOBS NOUN
# AND CCONJ
# INNOVATION NOUN
# We PRON
# will VERB
# kick VERB
# - PUNCT
# start NOUN
# investment NOUN
# in ADP
# innovation NOUN
# to PART
# grow VERB
# our ADJ
# economy NOUN
# and CCONJ
# create VERB
# good ADJ
# , PUNCT
# middle ADJ
# class NOUN
# jobs NOUN
# . PUNCT
# To PART
# get VERB
# our ADJ
# economy NOUN
# growing VERB
# again ADV
# , PUNCT
# we PRON
# need VERB
# to PART
# immediately ADV
# invest VERB
# in ADP
# helping VERB
# our ADJ
# businesses NOUN
# and CCONJ
# entrepreneurs NOUN
# including VERB
# those DET
# in ADP
# manufacturing NOUN
# become VERB
# more ADV
# innovative ADJ
# , PUNCT
# competitive ADJ
# , PUNCT
# and CCONJ
# successful ADJ
# . PUNCT
# Over ADP
# the DET
# next ADJ
# three NUM
# years NOUN
# , PUNCT
# we PRON
# will VERB
# : PUNCT
#   SPACE
# invest VERB
# $ SYM
# 200 NUM
# million NUM
# each DET
# year NOUN
# in ADP
# a DET
# new ADJ
# Innovation PROPN
# Agenda PROPN
# to PART
# significantly ADV
# expand VERB
# support NOUN
# for ADP
# incubators NOUN
# and CCONJ
# accelerators NOUN
# , PUNCT
# as ADV
# well ADV
# as ADP
# the DET
# emerging VERB
# national ADJ
# network NOUN
# for ADP
# business NOUN
# innovation NOUN
# and CCONJ
# cluster NOUN
# support NOUN
# ; PUNCT
# and CCONJ
#    SPACE
# invest VERB
# an DET
# additional ADJ
# $ SYM
# 100 NUM
# million NUM
# each DET
# year NOUN
# in ADP
# the DET
# Industrial PROPN
# Research PROPN
# Assistance PROPN
# Program PROPN
# , PUNCT
# which ADJ
# has VERB
# a DET
# proven VERB
# track NOUN
# record NOUN
# of ADP
# helping VERB
# small- ADJ
# and CCONJ
# medium ADJ
# - PUNCT
# sized ADJ
# businesses NOUN
# to PART
# innovate VERB
# and CCONJ
# become VERB
# world NOUN
# leaders NOUN
# . PUNCT
# AGRICULTURE NOUN
# We PRON
# will VERB
# help VERB
# Canada PROPN
# 's PART
# agriculture NOUN
# sector NOUN
# be VERB
# more ADV
# innovative ADJ
# , PUNCT
# safer ADJ
# , PUNCT
# and CCONJ
# stronger ADJ
# . PUNCT
# Canada PROPN
# 's PART
# farmers NOUN
# and CCONJ
# ranchers NOUN
# are VERB
# the DET
# foundation NOUN
# of ADP
# our ADJ
# food NOUN
# sector NOUN
# . PUNCT
# The DET
# work NOUN
# that ADJ
# they PRON
# do VERB
# to PART
# feed VERB
# Canada PROPN
# and CCONJ
# the DET
# world NOUN
# is VERB
# vital ADJ
# , PUNCT
# but CCONJ
# government NOUN
# support NOUN
# is VERB
# needed VERB
# to PART
# help VERB
# them PRON
# with ADP
# challenges NOUN
# ranging VERB
# from ADP
# transportation NOUN
# to ADP
# water NOUN
# management NOUN
# to PART
# research NOUN
# and CCONJ
# food NOUN
# safety NOUN
# . PUNCT
# To PART
# attract VERB
# investment NOUN
# and CCONJ
# create VERB
# good ADJ
# jobs NOUN
# in ADP
# food NOUN
# processing NOUN
# , PUNCT
# we PRON
# will VERB
# invest VERB
# $ SYM
# 160 NUM
# million NUM
# , PUNCT
# over ADP
# four NUM
# years NOUN
# , PUNCT
# in ADP
# an DET
# Agri PROPN
# - PUNCT
# Food PROPN
# Value PROPN
# Added PROPN
# Investment PROPN
# Fund PROPN
# . PUNCT
# This DET
# will VERB
# provide VERB
# technical ADJ
# and CCONJ
# marketing NOUN
# assistance NOUN
# to PART
# help VERB
# food NOUN
# processors NOUN
# develop VERB
# new ADJ
# value NOUN
# - PUNCT
# added VERB
# products NOUN
# that ADJ
# reflect VERB
# changing VERB
# tastes NOUN
# and CCONJ
# market NOUN
# opportunities NOUN
# . PUNCT
# To PART
# support VERB
# innovation NOUN
# in ADP
# the DET
# agricultural ADJ
# sector NOUN
# , PUNCT
# we PRON
# will VERB
# invest VERB
# an DET
# additional ADJ
# $ SYM
# 100 NUM
# million NUM
# , PUNCT
# over ADP
# four NUM
# years NOUN
# , PUNCT
# in ADP
# agricultural ADJ
# research NOUN
# . PUNCT
# To PART
# better ADV
# allocate VERB
# research NOUN
# funding NOUN
# , PUNCT
# we PRON
# will VERB
# establish VERB
# a DET
# transparent ADJ
# process NOUN
# that ADJ
# involves VERB
# food NOUN
# producers NOUN
# . PUNCT
# We PRON
# will VERB
# invest VERB
# an DET
# additional ADJ
# $ SYM
# 80 NUM
# million NUM
# , PUNCT
# over ADP
# four NUM
# years NOUN
# , PUNCT
# in ADP
# the DET
# Canadian PROPN
# Food PROPN
# Inspection PROPN
# Agency PROPN
# for ADP
# more ADJ
# food NOUN
# safety NOUN
# inspections NOUN
# of ADP
# domestic ADJ
# and CCONJ
# imported VERB
# foods NOUN
# . PUNCT
# We PRON
# will VERB
# continue VERB
# to PART
# defend VERB
# Canadian ADJ
# interests NOUN
# during ADP
# trade NOUN
# negotiations NOUN
# , PUNCT
# including VERB
# supply NOUN
# management NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# work VERB
# with ADP
# provinces NOUN
# , PUNCT
# territories NOUN
# , PUNCT
# and CCONJ
# other ADJ
# willing ADJ
# partners NOUN
# , PUNCT
# to PART
# better ADJ
# address NOUN
# water NOUN
# and CCONJ
# soil VERB
# conservation NOUN
# and CCONJ
# development NOUN
# issues NOUN
# , PUNCT
# including VERB
# investments NOUN
# in ADP
# appropriate ADJ
# infrastructure NOUN
# . PUNCT
# LABOUR VERB
# UNIONS NOUN
# We PRON
# will VERB
# ...
# China PROPN
# and CCONJ
# India PROPN
# . PUNCT
# We PRON
# will VERB
# develop VERB
# a DET
# new ADJ
# export NOUN
# promotion NOUN
# strategy NOUN
# that ADJ
# will VERB
# help VERB
# businesses NOUN
# take VERB
# advantage NOUN
# of ADP
# new ADJ
# trade NOUN
# agreements NOUN
# . PUNCT
# RENEWING VERB
# CANADA PROPN
# 'S PART
# PLACE PROPN
# IN ADP
# THE DET
# WORLD PROPN
# AND CCONJ
# STRENGTHENING VERB
# OUR ADJ
# SECURITY PROPN
# Canada PROPN
# 's PART
# future ADJ
# security NOUN
# and CCONJ
# prosperity NOUN
# go VERB
# hand NOUN
# - PUNCT
# in ADP
# - PUNCT
# hand NOUN
# . PUNCT
# Our ADJ
# plan NOUN
# will VERB
# ensure VERB
# that ADP
# Canada PROPN
# 's PART
# Armed PROPN
# Forces PROPN
# have VERB
# the DET
# equipment NOUN
# they PRON
# need VERB
# and CCONJ
# the DET
# support NOUN
# they PRON
# require VERB
# to PART
# protect VERB
# our ADJ
# sovereignty NOUN
# and CCONJ
# support VERB
# peace NOUN
# operations NOUN
# , PUNCT
# while ADP
# also ADV
# growing VERB
# local ADJ
# economies NOUN
# and CCONJ
# creating VERB
# jobs NOUN
# . PUNCT
# CANADA PROPN
# 'S PART
# LEADERSHIP PROPN
# IN ADP
# THE DET
# WORLD PROPN
# We PRON
# will VERB
# restore VERB
# Canadian ADJ
# leadership NOUN
# in ADP
# the DET
# world NOUN
# . PUNCT
# Canada PROPN
# has VERB
# a DET
# proud ADJ
# tradition NOUN
# of ADP
# international ADJ
# leadership NOUN
# , PUNCT
# from ADP
# helping VERB
# to PART
# create VERB
# the DET
# United PROPN
# Nations PROPN
# after ADP
# the DET
# Second PROPN
# World PROPN
# War PROPN
# , PUNCT
# to ADP
# the DET
# campaign NOUN
# against ADP
# South ADJ
# African ADJ
# apartheid NOUN
# , PUNCT
# to ADP
# the DET
# international ADJ
# treaty NOUN
# to PART
# ban VERB
# landmines NOUN
# . PUNCT
# Unfortunately ADV
# , PUNCT
# under ADP
# Stephen PROPN
# Harper PROPN
# , PUNCT
# our ADJ
# influence NOUN
# and CCONJ
# presence NOUN
# on ADP
# the DET
# world NOUN
# stage NOUN
# has VERB
# steadily ADV
# diminished VERB
# . PUNCT
# Instead ADV
# of ADP
# working VERB
# with ADP
# other ADJ
# countries NOUN
# constructively ADV
# at ADP
# the DET
# United PROPN
# Nations PROPN
# , PUNCT
# the DET
# Harper PROPN
# Conservatives PROPN
# have VERB
# turned VERB
# their ADJ
# backs NOUN
# on ADP
# the DET
# UN PROPN
# and CCONJ
# other ADJ
# multilateral ADJ
# institutions NOUN
# , PUNCT
# while ADP
# also ADV
# weakening VERB
# Canada PROPN
# 's PART
# military NOUN
# , PUNCT
# our ADJ
# diplomatic ADJ
# service NOUN
# , PUNCT
# and CCONJ
# our ADJ
# development NOUN
# programs NOUN
# . PUNCT
# Whether ADP
# confronting VERB
# climate NOUN
# change NOUN
# , PUNCT
# terrorism NOUN
# and CCONJ
# radicalization NOUN
# , PUNCT
# or CCONJ
# international ADJ
# conflicts NOUN
# , PUNCT
# the DET
# need NOUN
# for ADP
# effective ADJ
# Canadian ADJ
# diplomacy NOUN
# has VERB
# never ADV
# been VERB
# greater ADJ
# than ADP
# it PRON
# is VERB
# today NOUN
# . PUNCT
# Our ADJ
# plan NOUN
# will VERB
# restore VERB
# Canada PROPN
# as ADP
# a DET
# leader NOUN
# in ADP
# the DET
# world NOUN
# . PUNCT
# Not ADV
# only ADV
# to PART
# provide VERB
# greater ADJ
# security NOUN
# and CCONJ
# economic ADJ
# growth NOUN
# for ADP
# Canadians PROPN
# , PUNCT
# but CCONJ
# because ADP
# Canada PROPN
# can VERB
# make VERB
# a DET
# real ADJ
# and CCONJ
# valuable ADJ
# contribution NOUN
# to ADP
# a DET
# more ADV
# peaceful ADJ
# and CCONJ
# prosperous ADJ
# world NOUN
# . PUNCT
# PROMOTING VERB
# INTERNATIONAL PROPN
# PEACE PROPN
# AND CCONJ
# SECURITY PROPN
# We PRON
# will VERB
# renew VERB
# Canada PROPN
# 's PART
# commitment NOUN
# to ADP
# peacekeeping NOUN
# operations NOUN
# . PUNCT
# Under ADP
# Stephen PROPN
# Harper PROPN
# , PUNCT
# Canada PROPN
# has VERB
# dramatically ADV
# scaled VERB
# back PART
# its ADJ
# involvement NOUN
# in ADP
# peace NOUN
# operations NOUN
# a DET
# decision NOUN
# that ADJ
# could VERB
# not ADV
# come VERB
# at ADP
# a DET
# worse ADJ
# time NOUN
# . PUNCT
# As ADP
# the DET
# number NOUN
# of ADP
# violent ADJ
# conflicts NOUN
# in ADP
# the DET
# world NOUN
# escalates NOUN
# , PUNCT
# demand NOUN
# for ADP
# international ADJ
# peace NOUN
# operations NOUN
# has VERB
# never ADV
# been VERB
# greater ADJ
# . PUNCT
# Peace NOUN
# operations NOUN
# are VERB
# important ADJ
# not ADV
# only ADV
# because ADP
# of ADP
# the DET
# help NOUN
# they PRON
# provide VERB
# to ADP
# millions NOUN
# of ADP
# people NOUN
# affected VERB
# by ADP
# conflicts NOUN
# , PUNCT
# but CCONJ
# also ADV
# because ADP
# they PRON
# serve VERB
# Canada PROPN
# 's PART
# interests NOUN
# . PUNCT
# A DET
# more ADV
# peaceful ADJ
# world NOUN
# is VERB
# a DET
# safer ADJ
# and CCONJ
# more ADV
# prosperous ADJ
# world NOUN
# for ADP
# Canada PROPN
# , PUNCT
# too ADV
# . PUNCT
# We PRON
# will VERB
# recommit VERB
# to ADP
# supporting VERB
# international ADJ
# peace NOUN
# operations NOUN
# with ADP
# the DET
# United PROPN
# Nations PROPN
# , PUNCT
# and CCONJ
# will VERB
# make VERB
# our ADJ
# specialized ADJ
# capabilities NOUN
# from ADP
# mobile ADJ
# medical ADJ
# teams NOUN
# to ADP
# engineering NOUN
# support NOUN
# to ADP
# aircraft NOUN
# that ADJ
# can VERB
# carry VERB
# supplies NOUN
# and CCONJ
# personnel NOUN
# available ADJ
# on ADP
# a DET
# case NOUN
# - PUNCT
# by ADP
# - PUNCT
# case NOUN
# basis NOUN
# . PUNCT
# To PART
# help VERB
# the DET
# UN PROPN
# respond VERB
# more ADV
# quickly ADV
# to ADP
# emerging VERB
# and CCONJ
# escalating VERB
# conflicts NOUN
# , PUNCT
# we PRON
# will VERB
# provide VERB
# well ADV
# - PUNCT
# trained VERB
# personnel NOUN
# that ADJ
# can VERB
# be VERB
# quickly ADV
# deployed VERB
# , PUNCT
# including VERB
# mission NOUN
# commanders NOUN
# , PUNCT
# staff NOUN
# officers NOUN
# , PUNCT
# and CCONJ
# headquarters NOUN
# units NOUN
# . PUNCT
# We PRON
# will VERB
# prioritize VERB
# assistance NOUN
# for ADP
# civilian ADJ
# police NOUN
# training NOUN
# operations NOUN
# , PUNCT
# particularly ADV
# Francophone PROPN
# officers NOUN
# , PUNCT
# who NOUN
# are VERB
# in ADP
# great ADJ
# demand NOUN
# in ADP
# French PROPN
# - PUNCT
# speaking VERB
# countries NOUN
# with ADP
# peace NOUN
# operations NOUN
# . PUNCT
# We PRON
# will VERB
# lead VERB
# an DET
# international ADJ
# effort NOUN
# to PART
# improve VERB
# and CCONJ
# expand VERB
# the DET
# training NOUN
# of ADP
# military ADJ
# and CCONJ
# civilian ADJ
# personnel NOUN
# deployed VERB
# on ADP
# peace NOUN
# operations NOUN
# , PUNCT
# and CCONJ
# will VERB
# insist VERB
# that ADP
# any DET
# peacekeepers NOUN
# involved VERB
# in ADP
# misconduct NOUN
# be VERB
# held VERB
# accountable ADJ
# by ADP
# their ADJ
# own ADJ
# country NOUN
# and CCONJ
# the DET
# United PROPN
# Nations PROPN
# . PUNCT
# Finally ADV
# , PUNCT
# to PART
# better ADV
# help VERB
# those DET
# affected VERB
# by ADP
# war NOUN
# and CCONJ
# violent ADJ
# conflict NOUN
# , PUNCT
# we PRON
# will VERB
# contribute VERB
# more ADJ
# to ADP
# the DET
# United PROPN
# Nations PROPN
# ' PART
# mediation NOUN
# , PUNCT
# conflict NOUN
# - PUNCT
# prevention NOUN
# , PUNCT
# and CCONJ
# post NOUN
# - PUNCT
# conflict NOUN
# reconstruction NOUN
# efforts NOUN
# . PUNCT
# INVESTING VERB
# IN ADP
# OUR ADJ
# MILITARY NOUN
# We PRON
# will VERB
# maintain VERB
# current ADJ
# National PROPN
# Defence PROPN
# spending NOUN
# levels NOUN
# , PUNCT
# including VERB
# current ADJ
# planned VERB
# increases NOUN
# . PUNCT
# Under ADP
# Stephen PROPN
# Harper PROPN
# , PUNCT
# investments NOUN
# in ADP
# the DET
# Canadian PROPN
# Armed PROPN
# Forces PROPN
# have VERB
# been VERB
# erratic ADJ
# , PUNCT
# promised VERB
# increases NOUN
# in ADP
# funding NOUN
# have VERB
# been VERB
# scaled VERB
# back PART
# , PUNCT
# and CCONJ
# more ADJ
# than ADP
# $ SYM
# 10 NUM
# billion NUM
# of ADP
# approved ADJ
# funding NOUN
# was VERB
# left VERB
# unspent ADJ
# . PUNCT
# This DET
# mismanagement NOUN
# has VERB
# left VERB
# Canada PROPN
# 's PART
# Armed PROPN
# Forces PROPN
# underfunded VERB
# and CCONJ
# ill ADV
# - PUNCT
# equipped VERB
# , PUNCT
# and CCONJ
# the DET
# courageous ADJ
# members NOUN
# of ADP
# the DET
# Forces PROPN
# unsupported ADJ
# after ADP
# years NOUN
# of ADP
# dedicated ADJ
# service NOUN
# . PUNCT
# We PRON
# will VERB
# not ADV
# let VERB
# Canada PROPN
# 's PART
# Armed PROPN
# Forces PROPN
# be VERB
# shortchanged VERB
# , PUNCT
# and CCONJ
# we PRON
# will VERB
# not ADV
# lapse VERB
# military ADJ
# spending NOUN
# from ADP
# year NOUN
# to ADP
# year NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# reinvest VERB
# in ADP
# building VERB
# a DET
# leaner ADJ
# , PUNCT
# more ADV
# agile ADJ
# , PUNCT
# better ADV
# - PUNCT
# equipped VERB
# military NOUN
# , PUNCT
# including VERB
# adequate ADJ
# support NOUN
# systems NOUN
# for ADP
# military ADJ
# personnel NOUN
# and CCONJ
# their ADJ
# families NOUN
# . PUNCT
# F-35 PROPN
# We PRON
# will VERB
# not ADV
# buy VERB
# the DET
# F-35 PROPN
# stealth ADJ
# fighter NOUN
# - PUNCT
# bomber NOUN
# . PUNCT
# We PRON
# will VERB
# immediately ADV
# launch VERB
# an DET
# open ADJ
# and CCONJ
# transparent ADJ
# competition NOUN
# to PART
# replace VERB
# the DET
# CF-18 PROPN
# fighter NOUN
# aircraft NOUN
# . PUNCT
# The DET
# primary ADJ
# mission NOUN
# of ADP
# our ADJ
# fighter NOUN
# aircraft NOUN
# should VERB
# remain VERB
# the DET
# defence NOUN
# of ADP
# North PROPN
# America PROPN
# , PUNCT
# not ADV
# stealth ADJ
# first ADJ
# - PUNCT
# strike NOUN
# capability NOUN
# . PUNCT
# We PRON
# will VERB
# reduce VERB
# the DET
# procurement NOUN
# budget NOUN
# for ADP
# replacing VERB
# the DET
# CF-18s PROPN
# , PUNCT
# and CCONJ
# will VERB
# instead ADV
# purchase VERB
# one NUM
# of ADP
# the DET
# many ADJ
# , PUNCT
# lower ADV
# - PUNCT
# priced VERB
# options NOUN
# that ADJ
# better ADV
# match VERB
# Canada PROPN
# 's PART
# defence NOUN
# needs VERB
# . PUNCT
# ROYAL ADJ
# CANADIAN NOUN
# NAVY NOUN
# We PRON
# will VERB
# make VERB
# investing NOUN
# in ADP
# the DET
# Royal PROPN
# Canadian PROPN
# Navy PROPN
# a DET
# top ADJ
# priority NOUN
# . PUNCT
# By ADP
# purchasing VERB
# more ADV
# affordable ADJ
# alternatives NOUN
# to ADP
# the DET
# F-35s NOUN
# , PUNCT
# we PRON
# will VERB
# be VERB
# able ADJ
# to PART
# invest VERB
# in ADP
# strengthening VERB
# our ADJ
# Navy PROPN
# , PUNCT
# while ADP
# also ADV
# meeting VERB
# the DET
# commitments NOUN
# that ADJ
# were VERB
# made VERB
# as ADP
# part NOUN
# of ADP
# the DET
# National PROPN
# Shipbuilding PROPN
# and CCONJ
# Procurement PROPN
# Strategy PROPN
# . PUNCT
# Unlike ADP
# Stephen PROPN
# Harper PROPN
# , PUNCT
# we PRON
# will VERB
# have VERB
# the DET
# funds NOUN
# that ADJ
# we PRON
# need VERB
# to PART
# build VERB
# promised VERB
# icebreakers NOUN
# , PUNCT
# supply NOUN
# ships NOUN
# , PUNCT
# arctic ADJ
# and CCONJ
# offshore ADJ
# patrol NOUN
# ships NOUN
# , PUNCT
# surface NOUN
# combatants NOUN
# , PUNCT
# and CCONJ
# other ADJ
# resources NOUN
# required VERB
# by ADP
# the DET
# Navy PROPN
# . PUNCT
# These DET
# investments NOUN
# will VERB
# ensure VERB
# that ADP
# the DET
# Royal PROPN
# Canadian ADJ
# Navy PROPN
# is VERB
# able ADJ
# to PART
# operate VERB
# as ADP
# a DET
# true ADJ
# blue ADJ
# - PUNCT
# water NOUN
# maritime NOUN
# force NOUN
# , PUNCT
# while ADP
# also ADV
# growing VERB
# our ADJ
# economy NOUN
# and CCONJ
# creating VERB
# jobs NOUN
# . PUNCT
# STRATEGIC PROPN
# PRIORITIES PROPN
# We PRON
# will VERB
# immediately ADV
# begin VERB
# an DET
# open ADJ
# and CCONJ
# transparent ADJ
# review NOUN
# process NOUN
# of ADP
# existing VERB
# defence NOUN
# capabilities NOUN
# , PUNCT
# with ADP
# the DET
# goal NOUN
# of ADP
# delivering VERB
# a DET
# more ADV
# effective ADJ
# , PUNCT
# better ADV
# - PUNCT
# equipped VERB
# military NOUN
# . PUNCT
# The DET
# Canada PROPN
# First PROPN
# Defence PROPN
# Strategy PROPN
# , PUNCT
# launched VERB
# by ADP
# Stephen PROPN
# Harper PROPN
# in ADP
# 2008 NUM
# , PUNCT
# is VERB
# underfunded ADJ
# and CCONJ
# out ADP
# of ADP
# date NOUN
# . PUNCT
# We PRON
# will VERB
# review VERB
# current ADJ
# programs NOUN
# and CCONJ
# capabilities NOUN
# , PUNCT
# and CCONJ
# lay VERB
# out PART
# a DET
# realistic ADJ
# plan NOUN
# to PART
# strengthen VERB
# Canada PROPN
# 's PART
# Armed PROPN
# Forces PROPN
# . PUNCT
# We PRON
# will VERB
# develop VERB
# the DET
# Canadian PROPN
# Armed PROPN
# Forces PROPN
# into ADP
# an DET
# agile ADJ
# , PUNCT
# responsive ADJ
# , PUNCT
# and CCONJ
# well ADV
# - PUNCT
# equipped VERB
# military ADJ
# force NOUN
# that ADJ
# can VERB
# effectively ADV
# defend VERB
# Canada PROPN
# and CCONJ
# North PROPN
# America PROPN
# ; PUNCT
# provide VERB
# support NOUN
# during ADP
# natural ADJ
# disasters NOUN
# , PUNCT
# humanitarian ADJ
# support NOUN
# missions NOUN
# , PUNCT
# and CCONJ
# peace NOUN
# operations NOUN
# and CCONJ
# offer VERB
# international ADJ
# deterrence NOUN
# and CCONJ
# combat NOUN
# capability NOUN
# . PUNCT
# We PRON
# will VERB
# continue VERB
# to PART
# work VERB
# with ADP
# the DET
# United PROPN
# States PROPN
# to PART
# defend VERB
# North PROPN
# America PROPN
# under ADP
# NORAD PROPN
# , PUNCT
# and CCONJ
# contribute VERB
# to ADP
# regional ADJ
# security NOUN
# within ADP
# the DET
# North PROPN
# Atlantic PROPN
# Treaty PROPN
# Organization PROPN
# . PUNCT
# We PRON
# will VERB
# ensure VERB
# that DET
# equipment NOUN
# is VERB
# acquired VERB
# faster ADV
# , PUNCT
# and CCONJ
# with ADP
# vigorous ADJ
# Parliamentary ADJ
# oversight NOUN
# . PUNCT
# We PRON
# will VERB
# put VERB
# a DET
# renewed VERB
# focus NOUN
# on ADP
# surveillance NOUN
# and CCONJ
# control NOUN
# of ADP
# Canadian ADJ
# territory NOUN
# and CCONJ
# approaches NOUN
# , PUNCT
# particularly ADV
# our ADJ
# Arctic ADJ
# regions NOUN
# , PUNCT
# and CCONJ
# will VERB
# increase VERB
# the DET
# size NOUN
# of ADP
# the DET
# Canadian ADJ
# Rangers PROPN
# . PUNCT
# We PRON
# will VERB
# continue VERB
# to PART
# support VERB
# international ADJ
# peace NOUN
# and CCONJ
# security NOUN
# operations NOUN
# , PUNCT
# as ADV
# well ADV
# as ADP
# humanitarian ADJ
# support NOUN
# missions NOUN
# with ADP
# the DET
# United PROPN
# Nations PROPN
# or CCONJ
# regional ADJ
# partners NOUN
# , PUNCT
# on ADP
# a DET
# case NOUN
# - PUNCT
# by ADP
# - PUNCT
# case NOUN
# basis NOUN
# . PUNCT
# We PRON
# will VERB
# assist VERB
# in ADP
# domestic ADJ
# security NOUN
# and CCONJ
# natural ADJ
# disaster NOUN
# responses NOUN
# , PUNCT
# both CCONJ
# at ADP
# home NOUN
# and CCONJ
# abroad ADV
# . PUNCT
# To PART
# help VERB
# regional ADJ
# and CCONJ
# local ADJ
# partners NOUN
# prevent VERB
# the DET
# spread NOUN
# of ADP
# terrorism NOUN
# and CCONJ
# radicalization NOUN
# , PUNCT
# we PRON
# will VERB
# vastly ADV
# increase VERB
# the DET
# scope NOUN
# of ADP
# training NOUN
# assistance NOUN
# missions NOUN
# . PUNCT
# To PART
# bolster VERB
# these DET
# partnerships NOUN
# , PUNCT
# we PRON
# will VERB
# support VERB
# programs NOUN
# that ADJ
# admit VERB
# and CCONJ
# train NOUN
# partner NOUN
# country NOUN
# military ADJ
# students NOUN
# . PUNCT
# We PRON
# will VERB
# conduct VERB
# a DET
# thorough ADJ
# review NOUN
# of ADP
# existing VERB
# measures NOUN
# to PART
# protect VERB
# Canadians PROPN
# and CCONJ
# our ADJ
# critical ADJ
# infrastructure NOUN
# from ADP
# cyber NOUN
# - PUNCT
# threats NOUN
# . PUNCT
# Most ADV
# importantly ADV
# , PUNCT
# we PRON
# will VERB
# protect VERB
# the DET
# well ADV
# - PUNCT
# being NOUN
# of ADP
# Canadian PROPN
# Armed PROPN
# Forces PROPN
# members NOUN
# while ADP
# in ADP
# service NOUN
# , PUNCT
# including VERB
# a DET
# zero NUM
# - PUNCT
# tolerance NOUN
# policy NOUN
# for ADP
# sexual ADJ
# harassment NOUN
# , PUNCT
# adequate ADJ
# mental ADJ
# health NOUN
# support NOUN
# services NOUN
# , PUNCT
# and CCONJ
# high ADJ
# - PUNCT
# quality NOUN
# career NOUN
# counselling NOUN
# and CCONJ
# support NOUN
# . PUNCT
# We PRON
# will VERB
# also ADV
# make VERB
# new ADJ
# and CCONJ
# significant ADJ
# investments NOUN
# to PART
# meet VERB
# the DET
# sacred ADJ
# obligation NOUN
# that ADJ
# we PRON
# have VERB
# to ADP
# our ADJ
# veterans NOUN
# . PUNCT
# REPORT NOUN
# ON ADP
# TRANSFORMATION PROPN
# We PRON
# will VERB
# implement VERB
# the DET
# recommendations NOUN
# made VERB
# in ADP
# the DET
# Canadian PROPN
# Forces PROPN
# ' PART
# Report PROPN
# on ADP
# Transformation PROPN
# . PUNCT
# The DET
# Canadian PROPN
# Armed PROPN
# Forces PROPN
# ' PART
# ability NOUN
# to PART
# protect VERB
# Canada PROPN
# 's PART
# borders NOUN
# and CCONJ
# work VERB
# with ADP
# our ADJ
# allies NOUN
# overseas ADV
# should VERB
# never ADV
# be VERB
# compromised VERB
# . PUNCT
# Threats NOUN
# to ADP
# its ADJ
# ability NOUN
# to PART
# meet VERB
# future ADJ
# obligations NOUN
# must VERB
# be VERB
# addressed VERB
# head NOUN
# on ADV
# . PUNCT
# The DET
# Report PROPN
# on ADP
# Transformation PROPN
# made VERB
# a DET
# series NOUN
# of ADP
# recommendations NOUN
# on ADP
# how ADV
# to PART
# build VERB
# a DET
# more ADV
# modern ADJ
# , PUNCT
# efficient ADJ
# , PUNCT
# and CCONJ
# effective ADJ
# military NOUN
# , PUNCT
# including VERB
# reducing VERB
# the DET
# size NOUN
# of ADP
# administration NOUN
# within ADP
# government NOUN
# and CCONJ
# the DET
# Canadian PROPN
# Armed PROPN
# Forces PROPN
# in ADP
# order NOUN
# to PART
# strengthen VERB
# front ADJ
# - PUNCT
# line NOUN
# operations NOUN
# . PUNCT
# COMBAT NOUN
# MISSION NOUN
# IN ADP
# IRAQ NOUN
# We PRON
# will VERB
# end VERB
# Canada PROPN
# 's PART
# combat NOUN
# mission NOUN
# in ADP
# Iraq PROPN
# . PUNCT
# We PRON
# will VERB
# refocus VERB
# Canada PROPN
# 's PART
# military ADJ
# contribution NOUN
# in ADP
# the DET
# region NOUN
# on ADP
# the DET
# training NOUN
# of ADP
# local ADJ
# forces NOUN
# , PUNCT
# while ADP
# providing VERB
# more ADJ
# humanitarian ADJ
# support NOUN
# and CCONJ
# immediately ADV
# welcoming VERB
# 25,000 NUM
# more ADJ
# refugees NOUN
# from ADP
# Syria PROPN
# . PUNCT
# CENTRAL PROPN
# AND CCONJ
# EASTERN PROPN
# EUROPE PROPN
# We PRON
# will VERB
# remain VERB
# fully ADV
# committed ADJ
# to ADP
# Canada PROPN
# 's PART
# existing VERB
# military ADJ
# contributions NOUN
# in ADP
# Central ADJ
# and CCONJ
# Eastern PROPN
# Europe PROPN
# . PUNCT
# This DET
# includes VERB
# Canada PROPN
# 's PART
# participation NOUN
# in ADP
# NATO PROPN
# assurance NOUN
# measures NOUN
# in ADP
# Central ADJ
# and CCONJ
# Eastern PROPN
# Europe PROPN
# ( PUNCT
# Operation PROPN
# REASSURANCE PROPN
# ) PUNCT
# and CCONJ
# the DET
# multinational ADJ
# training NOUN
# mission NOUN
# in ADP
# Ukraine PROPN
# ( PUNCT
# Operation PROPN
# UNIFIER PROPN
# ) PUNCT
# . PUNCT

# %%
[(i, i.tag_) for i in l_nlp]
# Out:
# [(PLATEFORME, 'IN'),
#  (ELECTORALE, 'NNP'),
#  (PARTI, 'NNP'),
#  (LIBERAL, 'JJ'),
#  (DU, 'NNP'),
#  (CANADA, 'NNP'),
#  (2015, 'CD'),
#  (ECONOMIC, 'NNP'),
#  (SECURITY, 'NN'),
#  (FOR, 'IN'),
#  (THE, 'DT'),
#  (MIDDLE, 'JJ'),
#  (CLASS, 'NN'),
#  (A, 'DT'),
#  (strong, 'JJ'),
#  (economy, 'NN'),
#  (starts, 'VBZ'),
#  (with, 'IN'),
#  (a, 'DT'),
#  (strong, 'JJ'),
#  (middle, 'JJ'),
#  (class, 'NN'),
#  (., '.'),
#  (Our, 'PRP$'),
#  (plan, 'NN'),
#  (offers, 'VBZ'),
#  (real, 'JJ'),
#  (help, 'NN'),
#  (to, 'IN'),
#  (Canada, 'NNP'),
#  ('s, 'POS'),
#  (middle, 'JJ'),
#  (class, 'NN'),
#  (and, 'CC'),
#  (all, 'PDT'),
#  (those, 'DT'),
#  (working, 'VBG'),
#  (hard, 'RB'),
#  (to, 'TO'),
#  (join, 'VB'),
#  (it, 'PRP'),
#  (., '.'),
#  (When, 'WRB'),
#  (our, 'PRP$'),
#  (middle, 'JJ'),
#  (class, 'NN'),
#  (has, 'VBZ'),
#  (more, 'JJR'),
#  (money, 'NN'),
#  (in, 'IN'),
#  (their, 'PRP$'),
#  (pockets, 'NNS'),
#  (to, 'TO'),
#  (save, 'VB'),
#  (,, ','),
#  (invest, 'VB'),
#  (,, ','),
#  (and, 'CC'),
#  (grow, 'VB'),
#  (the, 'DT'),
#  (economy, 'NN'),
#  (,, ','),
#  (we, 'PRP'),
#  (all, 'DT'),
#  (benefit, 'VBP'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (give, 'VB'),
#  (families, 'NNS'),
#  (more, 'JJR'),
#  (money, 'NN'),
#  (to, 'TO'),
#  (help, 'VB'),
#  (with, 'IN'),
#  (the, 'DT'),
#  (high, 'JJ'),
#  (cost, 'NN'),
#  (of, 'IN'),
#  (raising, 'VBG'),
#  (their, 'PRP$'),
#  (kids, 'NNS'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (cancel, 'VB'),
#  (tax, 'NN'),
#  (breaks, 'NNS'),
#  (and, 'CC'),
#  (benefits, 'NNS'),
#  (for, 'IN'),
#  (the, 'DT'),
#  (wealthy, 'JJ'),
#  (including, 'VBG'),
#  (the, 'DT'),
#  (Universal, 'NNP'),
#  (Child, 'NNP'),
#  (Care, 'NNP'),
#  (Benefit, 'NNP'),
#  (€, ','),
#  (“, "''"),
#  (and, 'CC'),
#  (introduce, 'VB'),
#  (a, 'DT'),
#  (new, 'JJ'),
#  (Canada, 'NNP'),
#  (Child, 'NNP'),
#  (Benefit, 'NNP'),
#  (to, 'TO'),
#  (give, 'VB'),
#  (Canadian, 'JJ'),
#  (families, 'NNS'),
#  (more, 'JJR'),
#  (money, 'NN'),
#  (to, 'TO'),
#  (raise, 'VB'),
#  (their, 'PRP$'),
#  (kids, 'NNS'),
#  (., '.'),
#  (With, 'IN'),
#  (the, 'DT'),
#  (Canada, 'NNP'),
#  (Child, 'NNP'),
#  (Benefit, 'NNP'),
#  (,, ','),
#  (nine, 'CD'),
#  (out, 'IN'),
#  (of, 'IN'),
#  (ten, 'CD'),
#  (Canadian, 'JJ'),
#  (families, 'NNS'),
#  (will, 'MD'),
#  (receive, 'VB'),
#  (more, 'JJR'),
#  (than, 'IN'),
#  (under, 'IN'),
#  (Stephen, 'NNP'),
#  (Harper, 'NNP'),
#  ('s, 'POS'),
#  (confusing, 'JJ'),
#  (collection, 'NN'),
#  (of, 'IN'),
#  (child, 'NN'),
#  (benefit, 'NN'),
#  (programs, 'NNS'),
#  (., '.'),
#  (For, 'IN'),
#  (the, 'DT'),
#  (typical, 'JJ'),
#  (family, 'NN'),
#  (of, 'IN'),
#  (four, 'CD'),
#  (,, ','),
#  (that, 'WDT'),
#  (means, 'VBZ'),
#  (an, 'DT'),
#  (additional, 'JJ'),
#  ($, '$'),
#  (2,500, 'CD'),
#  (in, 'IN'),
#  (help, 'NN'),
#  (,, ','),
#  (tax, 'NN'),
#  (-, 'HYPH'),
#  (free, 'JJ'),
#  (,, ','),
#  (every, 'DT'),
#  (year, 'NN'),
#  (., '.'),
#  (Because, 'IN'),
#  (the, 'DT'),
#  (Canada, 'NNP'),
#  (Child, 'NNP'),
#  (Benefit, 'NNP'),
#  (is, 'VBZ'),
#  (tax, 'NN'),
#  (-, 'HYPH'),
#  (free, 'JJ'),
#  (and, 'CC'),
#  (tied, 'VBN'),
#  (to, 'TO'),
#  (income, 'NN'),
#  (,, ','),
#  (it, 'PRP'),
#  (also, 'RB'),
#  (provides, 'VBZ'),
#  (greater, 'JJR'),
#  (support, 'NN'),
#  (to, 'IN'),
#  (those, 'DT'),
#  (who, 'WP'),
#  (need, 'VBP'),
#  (help, 'VB'),
#  (the, 'DT'),
#  (most, 'RBS'),
#  (:, ':'),
#  (single, 'JJ'),
#  (-, 'HYPH'),
#  (parent, 'NN'),
#  (families, 'NNS'),
#  (and, 'CC'),
#  (low, 'JJ'),
#  (-, 'HYPH'),
#  (income, 'NN'),
#  (families, 'NNS'),
#  (., '.'),
#  (Our, 'PRP$'),
#  (plan, 'NN'),
#  (will, 'MD'),
#  (lift, 'VB'),
#  (315,000, 'CD'),
#  (Canadian, 'JJ'),
#  (children, 'NNS'),
#  (out, 'IN'),
#  (of, 'IN'),
#  (poverty, 'NN'),
#  (., '.'),
#  (Stephen, 'NNP'),
#  (Harper, 'NNP'),
#  (thinks, 'VBZ'),
#  (that, 'IN'),
#  (government, 'NN'),
#  (should, 'MD'),
#  (provide, 'VB'),
#  (child, 'NN'),
#  (support, 'NN'),
#  (payments, 'NNS'),
#  (to, 'IN'),
#  (millionaires, 'NNS'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (end, 'VB'),
#  (that, 'IN'),
#  (unfair, 'JJ'),
#  (giveaway, 'NN'),
#  (., '.'),
#  (MIDDLE, 'JJ'),
#  (CLASS, 'NN'),
#  (TAX, 'NN'),
#  (CUT, 'NNP'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (give, 'VB'),
#  (middle, 'JJ'),
#  (class, 'NN'),
#  (Canadians, 'NNPS'),
#  (a, 'DT'),
#  (tax, 'NN'),
#  (break, 'NN'),
#  (,, ','),
#  (by, 'IN'),
#  (making, 'VBG'),
#  (taxes, 'NNS'),
#  (more, 'RBR'),
#  (fair, 'JJ'),
#  (., '.'),
#  (When, 'WRB'),
#  (middle, 'JJ'),
#  (class, 'NN'),
#  (Canadians, 'NNPS'),
#  (have, 'VBP'),
#  (more, 'JJR'),
#  (money, 'NN'),
#  (in, 'IN'),
#  (their, 'PRP$'),
#  (pockets, 'NNS'),
#  (to, 'TO'),
#  (save, 'VB'),
#  (,, ','),
#  (invest, 'VB'),
#  (,, ','),
#  (and, 'CC'),
#  (grow, 'VB'),
#  (the, 'DT'),
#  (economy, 'NN'),
#  (,, ','),
#  (we, 'PRP'),
#  (all, 'DT'),
#  (benefit, 'VBP'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (cut, 'VB'),
#  (the, 'DT'),
#  (middle, 'JJ'),
#  (income, 'NN'),
#  (tax, 'NN'),
#  (bracket, 'NN'),
#  (to, 'IN'),
#  (20.5, 'CD'),
#  (percent, 'NN'),
#  (from, 'IN'),
#  (22, 'CD'),
#  (percent, 'NN'),
#  (a, 'DT'),
#  (seven, 'CD'),
#  (percent, 'NN'),
#  (reduction, 'NN'),
#  (., '.'),
#  (Canadians, 'NNS'),
#  (with, 'IN'),
#  (taxable, 'JJ'),
#  (annual, 'JJ'),
#  (income, 'NN'),
#  (between, 'IN'),
#  ($, '$'),
#  (44,700, 'CD'),
#  (and, 'CC'),
#  ($, '$'),
#  (89,401, 'CD'),
#  (will, 'MD'),
#  (see, 'VB'),
#  (their, 'PRP$'),
#  (income, 'NN'),
#  (tax, 'NN'),
#  (rate, 'NN'),
#  (fall, 'NN'),
#  (., '.'),
#  (This, 'DT'),
#  (tax, 'NN'),
#  (relief, 'NN'),
#  (is, 'VBZ'),
#  (worth, 'JJ'),
#  (up, 'IN'),
#  (to, 'TO'),
#  ($, '$'),
#  (670, 'CD'),
#  (per, 'IN'),
#  (person, 'NN'),
#  (,, ','),
#  (per, 'IN'),
#  (year, 'NN'),
#  (or, 'CC'),
#  ($, '$'),
#  (1,340, 'CD'),
#  (for, 'IN'),
#  (a, 'DT'),
#  (two, 'CD'),
#  (-, 'HYPH'),
#  (income, 'NN'),
#  (household, 'NN'),
#  (., '.'),
#  (To, 'TO'),
#  (pay, 'VB'),
#  (for, 'IN'),
#  (this, 'DT'),
#  (tax, 'NN'),
#  (cut, 'NN'),
#  (,, ','),
#  (we, 'PRP'),
#  (will, 'MD'),
#  (ask, 'VB'),
#  (the, 'DT'),
#  (wealthiest, 'JJS'),
#  (one, 'CD'),
#  (percent, 'NN'),
#  (of, 'IN'),
#  (Canadians, 'NNPS'),
#  (to, 'TO'),
#  (give, 'VB'),
#  (a, 'DT'),
#  (little, 'JJ'),
#  (more, 'JJR'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (introduce, 'VB'),
#  (a, 'DT'),
#  (new, 'JJ'),
#  (tax, 'NN'),
#  (bracket, 'NN'),
#  (of, 'IN'),
#  (33, 'CD'),
#  (percent, 'NN'),
#  (for, 'IN'),
#  (individuals, 'NNS'),
#  (earning, 'VBG'),
#  (more, 'JJR'),
#  (than, 'IN'),
#  ($, '$'),
#  (200,000, 'CD'),
#  (each, 'DT'),
#  (year, 'NN'),
#  (., '.'),
#  (ENDING, 'VBG'),
#  (UNFAIR, 'NNP'),
#  (TAX, 'NN'),
#  (BREAKS, 'NNS'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (cancel, 'VB'),
#  (income, 'NN'),
#  (splitting, 'NN'),
#  (and, 'CC'),
#  (other, 'JJ'),
#  (tax, 'NN'),
#  (breaks, 'NNS'),
#  (and, 'CC'),
#  (benefits, 'NNS'),
#  (for, 'IN'),
#  (the, 'DT'),
#  (wealthy, 'JJ'),
#  (., '.'),
#  (Income, 'NN'),
#  (splitting, 'NN'),
#  (costs, 'VBZ'),
#  (the, 'DT'),
#  (federal, 'JJ'),
#  (government, 'NN'),
#  ($, '$'),
#  (2, 'CD'),
#  (billion, 'CD'),
#  (a, 'DT'),
#  (year, 'NN'),
#  (but, 'CC'),
#  (delivers, 'VBZ'),
#  (benefits, 'NNS'),
#  (to, 'IN'),
#  (only, 'RB'),
#  (a, 'DT'),
#  (few, 'JJ'),
#  (., '.'),
#  (It, 'PRP'),
#  (will, 'MD'),
#  (not, 'RB'),
#  (create, 'VB'),
#  (a, 'DT'),
#  (single, 'JJ'),
#  (job, 'NN'),
#  (., '.'),
#  (It, 'PRP'),
#  (will, 'MD'),
#  (not, 'RB'),
#  (give, 'VB'),
#  (one, 'CD'),
#  (young, 'JJ'),
#  (person, 'NN'),
#  (an, 'DT'),
#  (opportunity, 'NN'),
#  (to, 'TO'),
#  (get, 'VB'),
#  (ahead, 'RB'),
#  (., '.'),
#  (Income, 'NN'),
#  (splitting, 'NN'),
#  (delivers, 'VBZ'),
#  (no, 'DT'),
#  (benefits, 'NNS'),
#  (to, 'IN'),
#  (working, 'VBG'),
#  (parents, 'NNS'),
#  (who, 'WP'),
#  (earn, 'VBP'),
#  (similar, 'JJ'),
#  (salaries, 'NNS'),
#  (,, ','),
#  (no, 'DT'),
#  (benefits, 'NNS'),
#  (to, 'IN'),
#  (single, 'JJ'),
#  (parents, 'NNS'),
#  (,, ','),
#  (and, 'CC'),
#  (no, 'DT'),
#  (benefits, 'NNS'),
#  (to, 'IN'),
#  (Canadians, 'NNPS'),
#  (who, 'WP'),
#  (do, 'VBP'),
#  (not, 'RB'),
#  (have, 'VB'),
#  (kids, 'NNS'),
#  (., '.'),
#  (All, 'DT'),
#  (told, 'VBD'),
#  (,, ','),
#  (income, 'NN'),
#  (splitting, 'NN'),
#  (benefits, 'NNS'),
#  (only, 'RB'),
#  (about, 'RB'),
#  (15, 'CD'),
#  (percent, 'NN'),
#  (of, 'IN'),
#  (Canadian, 'JJ'),
#  (households, 'NNS'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (cancel, 'VB'),
#  (Stephen, 'NNP'),
#  (Harper, 'NNP'),
#  ('s, 'POS'),
#  (tax, 'NN'),
#  (breaks, 'NNS'),
#  (for, 'IN'),
#  (the, 'DT'),
#  (wealthy, 'JJ'),
#  (,, ','),
#  (to, 'TO'),
#  (give, 'VB'),
#  (Canadian, 'JJ'),
#  (families, 'NNS'),
#  (more, 'JJR'),
#  (money, 'NN'),
#  (to, 'TO'),
#  (raise, 'VB'),
#  (their, 'PRP$'),
#  (children, 'NNS'),
#  (., '.'),
#  (OPPORTUNITIES, 'NNS'),
#  (FOR, 'IN'),
#  (YOUNG, 'JJ'),
#  (CANADIANS, 'NNS'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (invest, 'VB'),
#  (to, 'TO'),
#  (create, 'VB'),
#  (more, 'JJR'),
#  (jobs, 'NNS'),
#  (and, 'CC'),
#  (better, 'JJR'),
#  (opportunities, 'NNS'),
#  (for, 'IN'),
#  (young, 'JJ'),
#  (Canadians, 'NNPS'),
#  (., '.'),
#  (After, 'IN'),
#  (ten, 'CD'),
#  (years, 'NNS'),
#  (under, 'IN'),
#  (Stephen, 'NNP'),
#  (Harper, 'NNP'),
#  (,, ','),
#  (good, 'JJ'),
#  (-, 'HYPH'),
#  (quality, 'NN'),
#  (job, 'NN'),
#  (opportunities, 'NNS'),
#  (for, 'IN'),
#  (young, 'JJ'),
#  (Canadians, 'NNPS'),
#  (are, 'VBP'),
#  (tougher, 'JJR'),
#  (and, 'CC'),
#  (tougher, 'JJR'),
#  (to, 'TO'),
#  (find, 'VB'),
#  (., '.'),
#  (Faced, 'VBN'),
#  (with, 'IN'),
#  (high, 'JJ'),
#  (unemployment, 'NN'),
#  (and, 'CC'),
#  (underemployment, 'JJ'),
#  (,, ','),
#  (many, 'JJ'),
#  (young, 'JJ'),
#  (people, 'NNS'),
#  (have, 'VBP'),
#  (stopped, 'VBN'),
#  (looking, 'VBG'),
#  (for, 'IN'),
#  (work, 'NN'),
#  (altogether, 'RB'),
#  (., '.'),
#  (This, 'DT'),
#  (is, 'VBZ'),
#  (hard, 'JJ'),
#  (for, 'IN'),
#  (both, 'DT'),
#  (young, 'JJ'),
#  (people, 'NNS'),
#  (and, 'CC'),
#  (their, 'PRP$'),
#  (families, 'NNS'),
#  (., '.'),
#  (Many, 'JJ'),
#  (parents, 'NNS'),
#  (are, 'VBP'),
#  (seeing, 'VBG'),
#  (their, 'PRP$'),
#  (household, 'NN'),
#  (debt, 'NN'),
#  (rise, 'NN'),
#  (and, 'CC'),
#  (retirement, 'NN'),
#  (savings, 'NNS'),
#  (dwindle, 'VBP'),
#  (as, 'IN'),
#  (they, 'PRP'),
#  (struggle, 'VBP'),
#  (to, 'TO'),
#  (support, 'VB'),
#  (their, 'PRP$'),
#  (grown, 'JJ'),
#  (children, 'NNS'),
#  (,, ','),
#  (who, 'WP'),
#  (often, 'RB'),
#  (return, 'VBP'),
#  (home, 'RB'),
#  (., '.'),
#  (It, 'PRP'),
#  (is, 'VBZ'),
#  (time, 'NN'),
#  (to, 'TO'),
#  (invest, 'VB'),
#  (in, 'IN'),
#  (young, 'JJ'),
#  (Canadians, 'NNPS'),
#  (to, 'TO'),
#  (help, 'VB'),
#  (them, 'PRP'),
#  (get, 'VB'),
#  (the, 'DT'),
#  (work, 'NN'),
#  (experience, 'NN'),
#  (they, 'PRP'),
#  (will, 'MD'),
#  (need, 'VB'),
#  (to, 'TO'),
#  (start, 'VB'),
#  (their, 'PRP$'),
#  (careers, 'NNS'),
#  (and, 'CC'),
#  (contribute, 'VBP'),
#  (fully, 'RB'),
#  (to, 'IN'),
#  (our, 'PRP$'),
#  (economy, 'NN'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (create, 'VB'),
#  (40,000, 'CD'),
#  (good, 'JJ'),
#  (youth, 'NN'),
#  (jobs, 'NNS'),
#  (including, 'VBG'),
#  (5,000, 'CD'),
#  (youth, 'NN'),
#  (green, 'JJ'),
#  (jobs, 'NNS'),
#  (each, 'DT'),
#  (year, 'NN'),
#  (for, 'IN'),
#  (the, 'DT'),
#  (next, 'JJ'),
#  (three, 'CD'),
#  (years, 'NNS'),
#  (,, ','),
#  (by, 'IN'),
#  (investing, 'VBG'),
#  ($, '$'),
#  (300, 'CD'),
#  (million, 'CD'),
#  (more, 'JJR'),
#  (in, 'IN'),
#  (the, 'DT'),
#  (renewed, 'VBN'),
#  (Youth, 'NNP'),
#  (Employment, 'NNP'),
#  (Strategy, 'NNP'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (more, 'RBR'),
#  (than, 'IN'),
#  (double, 'PDT'),
#  (the, 'DT'),
#  (almost, 'RB'),
#  (11,000, 'CD'),
#  (Canadians, 'NNPS'),
#  (who, 'WP'),
#  (access, 'VBP'),
#  (Skills, 'NNPS'),
#  (Link, 'VBP'),
#  (each, 'DT'),
#  (year, 'NN'),
#  (., '.'),
#  (This, 'DT'),
#  (program, 'NN'),
#  (helps, 'VBZ'),
#  (young, 'JJ'),
#  (Canadians, 'NNPS'),
#  (including, 'VBG'),
#  (Aboriginal, 'JJ'),
#  (and, 'CC'),
#  (disabled, 'JJ'),
#  (youth, 'NN'),
#  (make, 'VBP'),
#  (a, 'DT'),
#  (more, 'RBR'),
#  (successful, 'JJ'),
#  (transition, 'NN'),
#  (to, 'IN'),
#  (the, 'DT'),
#  (workplace, 'NN'),
#  (., '.'),
#  (After, 'IN'),
#  (this, 'DT'),
#  (initial, 'JJ'),
#  (three, 'CD'),
#  (-, 'HYPH'),
#  (year, 'NN'),
#  (boost, 'NN'),
#  (in, 'IN'),
#  (funding, 'NN'),
#  (,, ','),
#  (we, 'PRP'),
#  (will, 'MD'),
#  (set, 'VB'),
#  (the, 'DT'),
#  (renewed, 'VBN'),
#  (Youth, 'NNP'),
#  (Employment, 'NNP'),
#  (Strategy, 'NNP'),
#  ('s, 'POS'),
#  (funding, 'NN'),
#  (level, 'NN'),
#  (at, 'IN'),
#  ($, '$'),
#  (385, 'CD'),
#  (million, 'CD'),
#  (per, 'IN'),
#  (year, 'NN'),
#  (a, 'DT'),
#  ($, '$'),
#  (50, 'CD'),
#  (million, 'CD'),
#  (increase, 'NN'),
#  (from, 'IN'),
#  (2015/16, 'CD'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (invest, 'VB'),
#  ($, '$'),
#  (40, 'CD'),
#  (million, 'CD'),
#  (each, 'DT'),
#  (year, 'NN'),
#  (to, 'TO'),
#  (help, 'VB'),
#  (employers, 'NNS'),
#  (create, 'VB'),
#  (more, 'JJR'),
#  (co, 'NN'),
#  (-, 'HYPH'),
#  (op, 'NN'),
#  (placements, 'NNS'),
#  (for, 'IN'),
#  (students, 'NNS'),
#  (in, 'IN'),
#  (science, 'NN'),
#  (,, ','),
#  (technology, 'NN'),
#  (,, ','),
#  (engineering, 'NN'),
#  (,, ','),
#  (mathematics, 'NNS'),
#  (,, ','),
#  (and, 'CC'),
#  (business, 'NN'),
#  (programs, 'NNS'),
#  (., '.'),
#  (And, 'CC'),
#  (to, 'TO'),
#  (encourage, 'VB'),
#  (companies, 'NNS'),
#  (to, 'TO'),
#  (hire, 'VB'),
#  (young, 'JJ'),
#  (Canadians, 'NNPS'),
#  (for, 'IN'),
#  (permanent, 'JJ'),
#  (positions, 'NNS'),
#  (,, ','),
#  (we, 'PRP'),
#  (will, 'MD'),
#  (also, 'RB'),
#  (offer, 'VB'),
#  (a, 'DT'),
#  (12-month, 'CD'),
#  (break, 'NN'),
#  (on, 'IN'),
#  (Employment, 'NNP'),
#  (Insurance, 'NNP'),
#  (premiums, 'NNS'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (waive, 'VB'),
#  (employer, 'NN'),
#  (premiums, 'NNS'),
#  (for, 'IN'),
#  (all, 'PDT'),
#  (those, 'DT'),
#  (between, 'IN'),
#  (the, 'DT'),
#  (ages, 'NNS'),
#  (of, 'IN'),
#  (18, 'CD'),
#  (and, 'CC'),
#  (24, 'CD'),
#  (who, 'WP'),
#  (are, 'VBP'),
#  (hired, 'VBN'),
#  (into, 'IN'),
#  (a, 'DT'),
#  (permanent, 'JJ'),
#  (position, 'NN'),
#  (in, 'IN'),
#  (2016, 'CD'),
#  (,, ','),
#  (2017, 'CD'),
#  (,, ','),
#  (or, 'CC'),
#  (2018, 'CD'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (also, 'RB'),
#  (work, 'VB'),
#  (with, 'IN'),
#  (provinces, 'NNS'),
#  (,, ','),
#  (territories, 'NNS'),
#  (,, ','),
#  (and, 'CC'),
#  (post, 'NN'),
#  (-, 'HYPH'),
#  (secondary, 'JJ'),
#  (institutions, 'NNS'),
#  (to, 'TO'),
#  (develop, 'VB'),
#  (or, 'CC'),
#  (expand, 'VB'),
#  (Pre, 'NNP'),
#  (-, 'HYPH'),
#  (Apprenticeship, 'NNP'),
#  (Training, 'NNP'),
#  (Programs, 'NNPS'),
#  (., '.'),
#  (This, 'DT'),
#  (will, 'MD'),
#  (provide, 'VB'),
#  (up, 'IN'),
#  (to, 'TO'),
#  ($, '$'),
#  (10, 'CD'),
#  (million, 'CD'),
#  (per, 'IN'),
#  (year, 'NN'),
#  (to, 'TO'),
#  (help, 'VB'),
#  (young, 'JJ'),
#  (Canadians, 'NNPS'),
#  (gain, 'VB'),
#  (the, 'DT'),
#  (skills, 'NNS'),
#  (they, 'PRP'),
#  (need, 'VBP'),
#  (to, 'TO'),
#  (enter, 'VB'),
#  (high, 'JJ'),
#  (-, 'HYPH'),
#  (demand, 'NN'),
#  (trades, 'NNS'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (end, 'VB'),
#  (the, 'DT'),
#  (rule, 'NN'),
#  (that, 'WDT'),
#  (discriminates, 'VBZ'),
#  (against, 'IN'),
#  (new, 'JJ'),
#  (workers, 'NNS'),
#  (and, 'CC'),
#  (those, 'DT'),
#  (re, 'NN'),
#  (-, 'HYPH'),
#  (entering, 'VBG'),
#  (the, 'DT'),
#  (workforce, 'NN'),
#  (by, 'IN'),
#  (requiring, 'VBG'),
#  (them, 'PRP'),
#  (to, 'TO'),
#  (accumulate, 'VB'),
#  (910, 'CD'),
#  (hours, 'NNS'),
#  (of, 'IN'),
#  (work, 'NN'),
#  (to, 'TO'),
#  (qualify, 'VB'),
#  (for, 'IN'),
#  (Employment, 'NNP'),
#  (Insurance, 'NNP'),
#  (benefits, 'NNS'),
#  (,, ','),
#  (including, 'VBG'),
#  (training, 'NN'),
#  (support, 'NN'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (invest, 'VB'),
#  ($, '$'),
#  (25, 'CD'),
#  (million, 'CD'),
#  (per, 'IN'),
#  (year, 'NN'),
#  (in, 'IN'),
#  (a, 'DT'),
#  (restored, 'VBN'),
#  (Youth, 'NNP'),
#  (Service, 'NNP'),
#  (Program, 'NNP'),
#  (,, ','),
#  (to, 'TO'),
#  (give, 'VB'),
#  (young, 'JJ'),
#  (Canadians, 'NNPS'),
#  (valuable, 'JJ'),
#  (work, 'NN'),
#  (and, 'CC'),
#  (life, 'NN'),
#  (experience, 'NN'),
#  (,, ','),
#  (and, 'CC'),
#  (provide, 'VB'),
#  (communities, 'NNS'),
#  (with, 'IN'),
#  (the, 'DT'),
#  (help, 'NN'),
#  (required, 'VBN'),
#  (for, 'IN'),
#  (much, 'RB'),
#  (-, 'HYPH'),
#  (needed, 'VBN'),
#  (projects, 'NNS'),
#  (., '.'),
#  (RETIREMENT, 'NNP'),
#  (SECURITY, 'NNP'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (provide, 'VB'),
#  (Canadians, 'NNPS'),
#  (with, 'IN'),
#  (a, 'DT'),
#  (more, 'RBR'),
#  (secure, 'JJ'),
#  (retirement, 'NN'),
#  (., '.'),
#  (After, 'IN'),
#  (a, 'DT'),
#  (lifetime, 'NN'),
#  (of, 'IN'),
#  (hard, 'JJ'),
#  (work, 'NN'),
#  (,, ','),
#  (Canadians, 'NNPS'),
#  (have, 'VBP'),
#  (earned, 'VBN'),
#  (a, 'DT'),
#  (secure, 'JJ'),
#  (and, 'CC'),
#  (dignified, 'JJ'),
#  (retirement, 'NN'),
#  (,, ','),
#  (but, 'CC'),
#  (too, 'RB'),
#  (many, 'JJ'),
#  (now, 'RB'),
#  (wonder, 'VBP'),
#  (when, 'WRB'),
#  (or, 'CC'),
#  (even, 'RB'),
#  (if, 'IN'),
#  (that, 'DT'),
#  (will, 'MD'),
#  (happen, 'VB'),
#  (., '.'),
#  (We, 'PRP'),
#  (will, 'MD'),
#  (help, 'VB'),
#  (Canadians, 'NNPS'),
#  (realize, 'VB'),
#  (their, 'PRP$'),
#  (goal, 'NN'),
#  (of, 'IN'),
#  (a, 'DT'),
#  (secure, 'JJ'),
#  (retirement, 'NN'),
#  ...]

# %%
lib_noun_chunks = [chunk.text for chunk in l_nlp.noun_chunks]
con_noun_chunks = [chunk.text for chunk in c_nlp.noun_chunks]
gre_noun_chunks = [chunk.text for chunk in g_nlp.noun_chunks]
ndp_noun_chunks = [chunk.text for chunk in n_nlp.noun_chunks]

# %%
Counter(ndp_noun_chunks).most_common(25)
# Out:
# [('The NDP', 91),
#  ('Canada', 70),
#  ('We', 66),
#  ('Canadians', 61),
#  ('we', 49),
#  ('it', 48),
#  ('they', 45),
#  ('the NDP', 34),
#  ('who', 26),
#  ('Stephen Harper', 25),
#  ('women', 24),
#  ('provinces', 19),
#  ('funding', 16),
#  ('territories', 16),
#  ('Indigenous communities', 16),
#  ('access', 15),
#  ('them', 15),
#  ('disabilities', 15),
#  ('It', 14),
#  ('the Conservatives', 14),
#  ('you', 13),
#  ('the provinces', 13),
#  ('Parliament', 13),
#  ('life', 12),
#  ('health care', 12)]

# %%
Counter(gre_noun_chunks).most_common(25)
# Out:
# [('We', 109),
#  ('we', 69),
#  ('Canada', 54),
#  ('Canadians', 32),
#  ('it', 29),
#  ('It', 27),
#  ('they', 23),
#  ('us', 19),
#  ('who', 19),
#  ('Parliament', 13),
#  ('government', 12),
#  ('time', 12),
#  ('our communities', 10),
#  ('people', 10),
#  ('all Canadians', 10),
#  ('education', 9),
#  ('you', 8),
#  ('access', 8),
#  ('Green MPs', 8),
#  ('I', 7),
#  ('our economy', 7),
#  ('the world', 7),
#  ('They', 7),
#  ('health care', 7),
#  ('First Nations', 7)]

# %%
Counter(con_noun_chunks).most_common(25)
# Out:
# [('we', 127),
#  ('We', 90),
#  ('it', 64),
#  ('Canadians', 62),
#  ('Canada', 62),
#  ('A re-elected Conservative Government', 62),
#  ('It', 36),
#  ('who', 35),
#  ('they', 32),
#  ('the world', 31),
#  ('them', 29),
#  ('jobs', 27),
#  ('taxes', 24),
#  ('our economy', 20),
#  ('families', 20),
#  ('Our Conservative Government', 19),
#  ('children', 19),
#  ('small businesses', 17),
#  ('the country', 16),
#  ('the next four years', 15),
#  ('what', 15),
#  ('Canadian families', 15),
#  ("Canada's economy", 14),
#  ('Canadian businesses', 14),
#  ('life', 13)]

# %%
Counter(lib_noun_chunks).most_common(25)
# Out:
# [('We', 361),
#  ('we', 109),
#  ('Canadians', 77),
#  ('it', 64),
#  ('Canada', 58),
#  ('they', 49),
#  ('who', 44),
#  ('Stephen Harper', 35),
#  ('territories', 31),
#  ('year', 22),
#  ('government', 20),
#  ('them', 19),
#  ('our economy', 19),
#  ('It', 18),
#  ('the provinces', 16),
#  ('provinces', 15),
#  ('investments', 15),
#  ('time', 14),
#  ('Parliament', 14),
#  ('part', 12),
#  ('our communities', 12),
#  ('funding', 11),
#  ('communities', 11),
#  ('support', 11),
#  ('Our plan', 10)]

# %%
print(set(gre_noun_chunks) & set(lib_noun_chunks))
# Out:
# {'health', 'omnibus bills', 'the resources', 'good jobs', 'terrorism', 'the burden', 'entrepreneurs', 'others', 'the rights', 'China', 'First Nations', 'provisions', 'research', 'its budget', 'what', 'our veterans', 'prorogation', 'WE', 'energy', 'injury', 'Canadians', 'our part', 'an election', 'cleaner air', 'benefits', 'Mtis', 'any Canadian', 'science', 'work', 'the same standard', 'kids', 'the Harper Conservatives', 'a world leader', 'carbon emissions', 'reserves', 'Canada Post', 'all parties', 'CANADA', 'affordable rental housing', 'more jobs', 'Calgary', 'the deficit', 'anyone', 'place', 'information', 'pocket', 'the federal government', 'courts', 'our country', 'the United States', 'Canadian workers', 'cooperation', 'decisions', 'the long-form census', 'Bill C-51', 'retirement', 'affordable housing', 'Cabinet', 'parents', 'billions', 'They', 'new Canadians', 'our communities', 'Ottawa', 'school', 'young Canadians', 'our sovereignty', 'subsidies', 'new funding', 'part', 'the provinces', 'the opportunity', 'a series', 'education', 'our coasts', 'them', 'Vancouver', 'post-secondary education', 'the foundation', 'consultation', 'communities', 'funding cuts', 'training', 'bridges', 'understanding', 'a decline', 'who', 'clean technology', 'families', 'the people', 'the Canadian economy', 'we', 'us', 'leadership', 'hard work', 'control', 'the table', 'the last decade', 'all First Nations', 'life', 'government', 'grandchildren', 'employers', 'the Senate', 'ends', 'a time', 'citizens', 'Our government', 'a barrier', 'a system', 'many young people', 'pride', 'this process', 'money', 'issues', 'the status quo', 'the House', 'a leader', 'the Fisheries Act', 'risk', 'health care', 'freedoms', 'innovation', 'line', "Canada's reputation", 'Indigenous communities', 'the Canada Council', 'child care', 'carbon', 'It', 'the construction', 'infrastructure', 'a transparent process', 'Canada', 'a result', 'the form', 'jobs', 'evidence', 'We', 'the skills', 'businesses', 'policies', 'funding', 'the Truth and Reconciliation Commission', 'their children', 'the fossil fuel industry', 'Our plan', 'public safety', 'the help', 'their communities', 'Parks Canada', 'transportation', 'progress', 'skills training', 'services', 'the Supreme Court', 'public policy', 'provinces', 'our government', 'people', 'the fairness', 'Stephen Harper', 'Telefilm Canada', 'Canadian families', 'more people', 'Canadian history', 'democracy', 'transit', 'our economy', '50 percent', 'support', 'the long-term', 'financing', 'nation', 'our children', 'partnership', 'market', 'Quebec', 'addition', 'the past decade', 'Commons', 'the past ten years', 'access', 'the process', 'dignity', 'our focus', 'order', 'the challenges', 'students', 'collaboration', 'the courts', 'relationships', 'the same time', 'living', 'facts', 'incentives', 'records', 'all Canadians', 'tax breaks', 'they', 'federal leadership', 'dollars', 'Veterans Affairs', 'our allies', 'a government', 'the role', 'millions', 'recognition', 'investment', 'cultures', 'the country', 'the power', 'scientists', 'our democracy', 'Access', 'governments', 'individuals', 'Inuit', 'CPP', 'the ground', 'the funds', 'companies', 'Members', 'an all-party committee', 'years', 'help', 'opportunities', 'problems', 'workers', 'a national strategy', 'the use', 'our rights', 'the funding', 'other countries', 'Canada Elections', 'the U.S.', 'home', 'our national broadcaster', 'behalf', 'it', 'poverty', 'year', 'an end', 'he', 'new jobs', 'accountability', 'First Nations communities', 'housing', 'public health', 'use', 'times', 'good faith', 'changes', 'the budget', 'the information', 'care', 'local economies', 'their expenses', 'the workplace', 'municipalities', 'Climate change', 'equality', 'climate change', 'the Commissioner', 'children', 'drugs', 'the land', 'languages', 'fear', 'time', 'reconciliation', 'day', 'their families', 'pollution', 'a reality', 'seniors', 'Health', 'the relationship', 'a country', 'traffic congestion', 't ...

# %% [markdown]
# # Named Entity Recognition

# %%
nlp.entity

toy = nlp('My cats Lando and Dorothy are sleeping next to me on the couch in our house in Kitchener.')
toy.ents
# Out:
# (Lando, Dorothy, Kitchener)

# %%
l_nlp.ents[:20]
# Out:
# (Canada,
#  Universal Child Care Benefit,
#  Canada,
#  Child Benefit,
#  Canadian,
#  the Canada Child Benefit,
#  nine,
#  ten,
#  Canadian,
#  Stephen Harper's,
#  four,
#  an additional $2,500,
#  Child Benefit,
#  315,000,
#  Canadian,
#  Stephen Harper,
#  MIDDLE CLASS,
#  Canadians,
#  Canadians,
#  20.5 percent)

# %%
for ent in l_nlp.ents:
    print(ent,ent.label_)

for ent in l_nlp.ents:
    if ent.label_ == "NORP":
        print(ent)
# Out:
# Canada GPE
# Universal Child Care Benefit ORG
# Canada GPE
# Child Benefit PERSON
# Canadian NORP
# the Canada Child Benefit ORG
# nine CARDINAL
# ten CARDINAL
# Canadian NORP
# Stephen Harper's PERSON
# four CARDINAL
# an additional $2,500 MONEY
# Child Benefit PERSON
# 315,000 CARDINAL
# Canadian NORP
# Stephen Harper PERSON
# MIDDLE CLASS PERSON
# Canadians NORP
# Canadians NORP
# 20.5 percent PERCENT
# 22 percent PERCENT
# seven percent PERCENT
# Canadians NORP
# annual DATE
# between $44,700 and $89,401 MONEY
# up to $670 MONEY
# 1,340 MONEY
# two CARDINAL
# one percent PERCENT
# Canadians NORP
# 33 percent PERCENT
# more than $200,000 MONEY
# each year DATE
# $2 billion MONEY
# one CARDINAL
# Canadians NORP
# 15 percent PERCENT
# Canadian NORP
# Stephen Harper's PERSON
# Canadian NORP
# Canadians NORP
# ten years DATE
# Stephen Harper PERSON
# Canadians NORP
# Canadians NORP
# 40,000 CARDINAL
# 5,000 CARDINAL
# the next three years DATE
# $300 million MONEY
# Youth Employment PERSON
# 11,000 CARDINAL
# Canadians NORP
# Skills Link each year LOC
# Canadians NORP
# Aboriginal WORK_OF_ART
# three-year DATE
# Youth Employment Strategy 's PERSON
# $385 million MONEY
# $50 million MONEY
# 2015/16 CARDINAL
# $40 million MONEY
# each year DATE
# Canadians NORP
# 12-month GPE
# Employment Insurance ORG
# between the ages of 18 DATE
# 2016 DATE
# 2017 DATE
# 2018 DATE
# Pre-Apprenticeship Training Programs ORG
# $10 million MONEY
# Canadians NORP
# 910 hours TIME
# $25 million MONEY
# Youth Service Program ORG
# Canadians NORP
# Canadians NORP
# Canadians NORP
# Canadians NORP
# the Canada Pension Plan EVENT
# 65 CARDINAL
# 13,000 MONEY
# Canadians NORP
# hundreds of thousands CARDINAL
# Income Supplement PERSON
# ten percent PERCENT
# one million CARDINAL
# almost $1,000 MONEY
# each year DATE
# Old Age Security ORG
# the Compassionate Care Benefit WORK_OF_ART
# six months DATE
# Canadians NORP
# Today DATE
# one CARDINAL
# four CARDINAL
# Canadian NORP
# one CARDINAL
# eight CARDINAL
# Canadians NORP
# ten-year DATE
# Housing First ORG
# Canadians NORP
# GST ORG
# $125 million MONEY
# Canada GPE
# Home Buyers' Plan ORG
# Canadians NORP
# Canadians NORP
# the Canada Mortgage and Housing Corporation ORG
# Canada Infrastructure Bank ORG
# Canadians NORP
# Toronto GPE
# Vancouver GPE
# Canadians NORP
# Canadians NORP
# billions CARDINAL
# each year DATE
# Canada GPE
# Student Grant ORG
# 3,000 MONEY
# 1,800 MONEY
# Canada GPE
# Canadian NORP
# $750 million MONEY
# $850 million MONEY
# 2019/20 CARDINAL
# at least $25,000 MONEY
# the Canada Student Loan ORG
# $50 million MONEY
# annual DATE
# the Post-Secondary Student Support Program ORG
# Indigenous PERSON
# A NEW HEALTH ACCORD We LAW
# Canada GPE
# Canadians NORP
# Canadians NORP
# more than a decade DATE
# Canadian NORP
# Premiers PERSON
# the Harper decade DATE
# $3 billion MONEY
# the next four years DATE
# Canadians NORP
# the Employment Insurance Compassionate Care Benefit ORG
# Canadian NORP
# Canadian NORP
# Canadians NORP
# Canadians NORP
# first ORDINAL
# Canadians NORP
# National Disabilities Act EVENT
# Canadians NORP
# Canadians NORP
# Canada GPE
# Canadians NORP
# Canada GPE
# Canadians NORP
# Canada GPE
# Child Benefit WORK_OF_ART
# monthly DATE
# 315,000 CARDINAL
# hundreds of thousands CARDINAL
# Income Supplement PERSON
# ten percent PERCENT
# one million CARDINAL
# almost $1,000 MONEY
# each year DATE
# Housing First ORG
# Canadians NORP
# THE MIDDLE CLASS LOC
# Stephen Harper PERSON
# Canada GPE
# less than $10 billion MONEY
# each of the next two fiscal years DATE
# the next two fiscal years DATE
# Canada GPE
# 2019 DATE
# Canadian NORP
# Stephen Harper's PERSON
# billions of dollars MONEY
# each year DATE
# the next decade DATE
# almost $20 billion MONEY
# Canada GPE
# British Columbia's GPE
# Lower Mainland LOC
#   NORP
# ¢ PERSON
# every ten minutes TIME
# afternoon TIME
# Broadway FAC
# North America LOC
#   NORP
# ¢ PERSON
# Surrey PERSON
# one CARDINAL
# millions CARDINAL
# Canadians NORP
# First Nations ORG
# National Early Learning ORG
# Child Care Framework ORG
# the next decade DATE
# almost $20 billion MONEY
# Canada GPE
# Toronto GPE
# Alexandra Park GPE
# Alexandra Park GPE
# Canada GPE
# GREENER COMMUNITIES PERSON
# nearly $6 billion MONEY
# the next four years DATE
# almost $20 billion MONEY
# ten years DATE
# Canadians NORP
# St. John's GPE
# Trois-Rivi¨res FAC
# Maples PRODUCT
# Cardinal-Roy PRODUCT
# Millette GPE
# Bettez PERSON
# Lacerte ORG
# Calgary GPE
# Southern Alberta PERSON
# NEW BUILDING CANADA FUND ORG
# the New Building Canada Fund ORG
# The New Building Canada Fund ORG
# Canadian NORP
# more than 70 percent PERCENT
# 2019 DATE
# the New Building Canada Fund ORG
# the New Building Canada Fund ORG
# Canada GPE
# Canada GPE
# COMMITMENT PERSON
# Stephen Harper PERSON
# the end of the fiscal year DATE
# the Gas Tax Fund ORG
# CANADA INFRASTRUCTURE BANK ORG
# the Canadian Infrastructure Bank ORG
# the Canada Infrastructure Bank ORG
# Canadians NORP
# Canadians NORP
# $500 million MONEY
# each year DATE
# Labour Market Development Agreements ORG
# an additional $200 million MONEY
# $50 million MONEY
# the Aboriginal Skills and Employment Training Strategy WORK_OF_ART
# $25 million MONEY
# each year DATE
# an additional $775 million MONEY
# Canadians NORP
# JOBS ORG
# the next three years DATE
#   NORP
# $200 million MONEY
# each year DATE
# Innovation Agenda PRODUCT
#    ORG
# an additional $100 million MONEY
# each year DATE
# the Industrial Research Assistance Program ORG
# Canada GPE
# Canada GPE
# Canada GPE
# $160 million MONEY
# four years DATE
# Agri-Food Value Added Investment Fund ORG
# an additional $100 million MONEY
# four years DATE
# an additional $80 million MONEY
# four years DATE
# the Canadian Food Inspection Agency ORG
# Canadian NORP
# Canada GPE
# Labour ORG
# Stephen Harper PERSON
# Canada GPE
# Bills C-377 ORG
# C-525 GPE
# Canada GPE
# Canada GPE
# LABOUR-SPONSORED PERSON
# Canadians NORP
# Quebec GPE
# 650,000 CARDINAL
# Canada GPE
# Canadians NORP
# Harper NORP
# CANADIAN NORP
# Canadians NORP
# daily DATE
# Canadian NORP
# Canadian NORP
# up to 18 months DATE
# up to 18 months DATE
# Canadians NORP
# $125 million MONEY
# Canadian NORP
# Millions CARDINAL
# Canadians NORP
# Employment Insurance PERSON
# Canadian NORP
# year-long DATE
# the six months DATE
#   NORP
# $190 million MONEY
# Canada GPE
# the Canada Labour Code EVENT
# the United Kingdom GPE
# EMPLOYMENT INSURANCE PERSON
# Employment Insurance ORG
# Canadians NORP
# Canada GPE
# Canadians NORP
# Canadians NORP
# 2017 DATE
# Employment Insurance PERSON
# one week DATE
# two CARDINAL
# Stephen Harper's PERSON
# 2012 DATE
# EI ORG
# Canadian NORP
# one CARDINAL
# Indigenous PERSON
# National Early Learning ORG
# Child Care Framework ORG
# Canadian NORP
# the first 100 days DATE
# Canadian NORP
#   NORP
# Quebec GPE
# U.S. GPE
#   NORP
# Canadian NORP
# the Public Health Agency ORG
# Canada GPE
# $15 million MONEY
# each of the next two years DATE
# Australia GPE
# the United Kingdom GPE
# Early Childhood Educator School Supply Tax Benefit ORG
# up to $1,000 MONEY
# each year DATE
# up to $150 MONEY
# the 2015 tax year DATE
# CANADA GPE
# NORTH GPE
# Canada GPE
# North GPE
# Canadians NORP
# Canada GPE
# North GPE
# The Northern Residents Deduction LAW
# North LOC
# 33 percent PERCENT
# 22 MONEY
# Nutrition North ORG
# $40 million MONEY
# four years DATE
# Canadians NORP
# ten-year DATE
# Canadians NORP
# Canada GPE
# Northern Zone LOC
# Northern Residents Deduction LOC
# 8,000 MONEY
# 6,022 MONEY
# the Intermediate Zone LOC
# annual DATE
# 4,000 MONEY
# 3,011 MONEY
# $50 million MONEY
# annual DATE
# Northern Canadians NORP
# CHAPTER TWO FAIR AND OPEN GOVERNMENT OPEN LAW
# TRANSPARENT GOVERNMENT ORG
# Canadians NORP
# Canadians NORP
# Canadians NORP
# the Access to Information Act ORG
# Canadians NORP
# 5 MONEY
# Access to Information ORG
# Ministers' Offices ORG
# Parliament ORG
# Canadians NORP
# the Access to Information Act ORG
# every five years DATE
# Canadians NORP
# Canadians NORP
# 30-day DATE
# longer than 30 days DATE
# Privacy ORG
# Canadians NORP
# PARLIAMENT ORG
# Parliament ORG
# The Liberal Party ORG
# first ORDINAL
# Parliamentarians NORP
# Parliamentarians NORP
# each quarter DATE
# the Board of Internal Economy the ORG
# Members of Parliament. ORG
# FAIR ORG
# Canadians NORP
# Advertising ORG
# the Auditor General ORG
# Canadians NORP
# Fair ORG
# Elections Canada ORG
# Canadians NORP
# Canada GPE
# Canada Elections ORG
# Parliament ORG
# the day DATE
# Canadians NORP
# Canadians NORP
# Parliamentary GPE
# Parliament ORG
# 18 months DATE
# first ORDINAL
# Canadians NORP
# 18 CARDINAL
# Elections Canada ORG
# Canadians NORP
# Elections Canada ORG
# Elections Canada ORG
# Canadians NORP
# LAW PERSON
# Canadians NORP
# Stephen Harper's PERSON
# Fair Elections Act WORK_OF_ART
# Canadians NORP
# OTTAWA GPE
# Parliament ORG
# Canadians NORP
# SENATE ORG
# Senate ORG
# Senate ORG
# Senate ORG
# Canadians NORP
# Senate ORG
# Canadians NORP
# Canadians NORP
# Question Period PERSON
# the House of Commons ORG
# Canadians NORP
# the House of Commons ORG
# Liberal ORG
# Parliament ORG
# Cabinet ORG
# the Liberal Caucus ORG
#   NORP
# Liberal ORG
# the Charter of Rights LAW
# Freedoms ORG
# OMNIBUS ORG
# Stephen Harper PERSON
# Stephen Harper PERSON
# Parliament ORG
# the House of Commons Standing Orders ORG
# Parliament ORG
# Canadians NORP
# Parliament ORG
# the day DATE
# SUPREME COURT ORG
# the Supreme Court ORG
# Stephen Harper PERSON
# Supreme Court ORG
# the Supreme Court ORG
# the House of Commons ORG
# Supreme Court ORG
# Canadians NORP
# the Supreme Court ORG
# the Supreme Court ORG
# the Parliamentary Budget Officer LAW
# the Parliamentary Budget Officer LAW
# Parliament ORG
# the day DATE
# Canadians NORP
# the Parliamentary Budget Officer's ORG
# Canadians NORP
# Canadians NORP
# Parliament ORG
# Estimates ORG
# the Public Accounts ORG
# Parliament ORG
# Parliament ORG
# Canada GPE
# Five CARDINAL
# Eyes ORG
# Parliamentary GPE
# BETTER SERVICE FOR CANADIANS ORG
# Canadians NORP
# Canadians NORP
# CANADA REVENUE AGENCY ORG
# the Canada Revenue Agency ORG
# The Canada Revenue Agency ORG
# Canadians NORP
# CRA ORG
# Canada Revenue Agency ORG
# Canadians NORP
# Canadians NORP
# year-to-year DATE
# Canadians NORP
#    NORP
# Canadians NORP
# an additional $80 million MONEY
# four years DATE
# the Canada Revenue Agency ORG
# CANADA POST ORG
# Stephen Harper PERSON
# Canadians NORP
# Stephen Harper's PERSON
# Canada GPE
# Canada Post ORG
# Canadians NORP
# Canada GPE
# Canada GPE
# Cabinet ORG
# Canada GPE
# Youth Advisory Council ORG
# Canadians NORP
# 16 to 24 DATE
# Cabinet ORG
# the past 20 years DATE
# Canadians NORP
# nine CARDINAL
# Stephen Harper PERSON
# Privacy ORG
# Canadians NORP
# QUALITY OF SERVICE ORG
# Canadians NORP
# Stephen Harper PERSON
# Employment Insurance PERSON
# EI ORG
# CPP ORG
# the Official Languages Act LAW
# Canadians NORP
# Common PERSON
# Canada GPE
# Canadians NORP
# Canadians NORP
# STATISTICS CANADA ORG
# Statistics Canada ORG
# Statistics Canada ORG
# Statistics Canada ORG
# Statistics Canada ORG
# Canadians NORP
# CHAPTER THREE LAW
# CLEAN ENVIRONMENT ORG
# STRONG ECONOMY Canadians ORG
# Stephen Harper PERSON
# Canadians NORP
# one CARDINAL
# Stephen Harper PERSON
# nearly a decade DATE
# Canada GPE
# Canadian NORP
# Paris GPE
# 90 days DATE
# Canadian NORP
# two CARDINAL
# Canada GPE
# Low Carbon Economy Trust ORG
# Trust ORG
# Canadian NORP
# the Low Carbon Economy Trust ORG
# $2 billion MONEY
# G20 PERSON
# the United States GPE
# Mexico GPE
# North American NORP
# CLEAN ORG
# JOBS PRODUCT
# Canadian NORP
# $100 million MONEY
# each year DATE
# Canada GPE
# Canadian NORP
# $200 million MONEY
# each year DATE
# Canada Infrastructure Bank ORG
# Green Bonds PRODUCT
# Canada GPE
# Canadians NORP
# Canada GPE
# Canada Research Chairs ORG
# Canadian NORP
# Canada GPE
# Canada GPE
# 71% PERCENT
# the harper decade DATE
# Resource ORG
# Canadians NORP
# Indigenous PERSON
# Canada GPE
# Canadians NORP
#   NORP
# the National Energy Board ORG
# First Nations ORG
# Inuit NORP
# the Mtis Nation ORG
# Crown ORG
# Aboriginal and Treaty LAW
# the United Nations Declaration on the Rights of Indigenous Peoples LAW
# Indigenous Peoples PERSON
# Stephen Harper's PERSON
# the Fisheries Act LAW
# the Navigable Waters Protection Act ORG
# Canada GPE
# Canada GPE
# nearly $40 billion MONEY
# each year DATE
# Canadian NORP
# Canada GPE
# the Great Lakes LOC
# the St. Lawrence River Basin LOC
# the Lake Winnipeg Basin LOC
# the Cohen Commission ORG
# the Fraser River LOC
# $1.5 million MONEY
# annual DATE
# Conservatives NORP
# Canada GPE
# Experimental Lakes Area LOC
# Stephen Harper's PERSON
# Canada GPE
# five percent PERCENT
# 2017 DATE
# ten percent PERCENT
# 2020 DATE
# $8 million MONEY
# Stephen Harper PERSON
# $40 million MONEY
# Indigenous Peoples PERSON
# PARKS ORG
# Canada GPE
# National Parks GPE
# Canada GPE
# National Parks GPE
# Canadians NORP
# nearly $5 billion MONEY
# each year DATE
# 65,000 CARDINAL
# Canadians NORP
# National Parks PERSON
# 2017 DATE
# 150th ORDINAL
# Confederation ORG
# National Parks ORG
# 2018 DATE
# under 18 DATE
# Canadian NORP
# the previous 12 months DATE
# one year's DATE
# Learn PERSON
# Camp ORDINAL
# Canada GPE
# $25 million MONEY
# each year DATE
# Canada GPE
# National Parks LOC
# National Wildlife Areas and Migratory Bird Sanctuaries ORG
# Stephen Harper's PERSON
# Parks Canada ORG
# more than $25 million MONEY
# Canadians NORP
# National Parks PERSON
# Ontario GPE
# first ORDINAL
# National Park Rouge National Park ORG
# FOUR CARDINAL
# STRONG CANADA ORG
# Canada GPE
# Indigenous Peoples PERSON
# Canada GPE
# Indigenous Peoples PERSON
# Canada GPE
# Indigenous Peoples PERSON
# Indigenous Peoples PERSON
# First Nations ORG
# the Mtis Nation ORG
# Inuit NORP
# Indigenous Peoples PERSON
# Ottawa GPE
# Justin Trudeau PERSON
# First Nations ORG
# Mtis Nation ORG
# Inuit NORP
# Liberal ORG
# Stephen Harper's PERSON
# the Canada Elections Act LAW
# Indigenous Peoples PERSON
# Accord PRODUCT
# today DATE
# A NEW FISCAL RELATIONSHIP EVENT
# First Nations ORG
# First Nations ORG
# nearly 20 years DATE
# First Nations ORG
# two percent PERCENT
# annual DATE
# First Nations ORG
# two percent PERCENT
# First Nations ORG
# First Nations ORG
# Increasing First Nations' ORG
# First Nations ORG
# FIRST ORDINAL
# First Nations ORG
# First Nations ORG
# Canadians NORP
# First Nations ORG
# Chronic ORG
# First Nations ORG
# First Nations ORG
# Today DATE
# less than half CARDINAL
# First Nations ORG
# each year DATE
# 12 CARDINAL
# Stephen Harper PERSON
# an additional $300 million MONEY
# $750 million MONEY
# the end of our first DATE
# the next four years DATE
# $2.6 billion MONEY
# First Nations ORG
# an additional $500 million MONEY
# the next three years DATE
# First Nations ORG
# $50 million MONEY
# annual DATE
# the Post-Secondary Student Support Program ORG
# Indigenous PERSON
# First Nations' ORG
# First Nations ORG
# METIS NATION ORG
# the Mtis Nation ORG
# Mtis ORG
# the Mtis Nation ORG
# Mtis ORG
# Mtis ORG
# Mtis ORG
# Mtis FAC
# year-to-year DATE
# Mtis ORG
# the Mtis Nation ORG
# Mtis ORG
# Mtis ORG
# Mtis Economic Development Strategy ORG
# Mtis ORG
# Mtis ORG
# $25 million MONEY
# five years DATE
# Indigenous PERSON
# Canada GPE
# 1,200 CARDINAL
# Indigenous PERSON
# Indigenous PERSON
# Canada GPE
# the Truth and Reconciliation Commission ORG
# First Nations ORG
# the Mtis Nation ORG
# Inuit NORP
# the Truth and Reconciliation Commission ORG
# the United Nations Declaration on the Rights of Indigenous Peoples LAW
# OUR VETERANS Veterans ORG
# Canadians NORP
# VETERANS ORG
# $25 million MONEY
# each year DATE
# the Permanent Impairment Allowance ORG
# $40 million MONEY
# each year DATE
# 90 percent PERCENT
# Veterans Education Benefit ORG
# Veterans ORG
# their years DATE
# Canada GPE
# $80 million MONEY
# every year DATE
# Veterans Education Benefit ORG
# up to four years DATE
# Canadian Forces ORG
# the Community Benefits Agreements ORG
# BETTER SERVICE ORG
# one CARDINAL
# one CARDINAL
# nine CARDINAL
# Veterans Affairs ORG
# Stephen Harper PERSON
# the Auditor General's ORG
# 400 CARDINAL
# Veterans Affairs ORG
# Canada GPE
# Liberal ORG
# $20 million MONEY
# two CARDINAL
# one CARDINAL
# first ORDINAL
# VETERANS ORG
# Canada GPE
# Veterans ORG
# Canada GPE
# $100 million MONEY
# each year DATE
# 50 percent PERCENT
# 70 percent PERCENT
# Veterans ORG
# Canada GPE
# the Last Post Fund ORG
# Canada GPE
# Canadians NORP
# Canadians NORP
# daily DATE
# Canada GPE
# the Criminal Code LAW
# Parliament ORG
# RCMP ORG
# the Canadian Armed Forces ORG
# Canada GPE
# Canada GPE
# two-year DATE
# Indigenous PERSON
# Canada GPE
# BILL C-51 PERSON
# Bill C-51 PERSON
# Canadians NORP
# Canada GPE
# all Canadian Security Intelligence Service ORG
# the Charter of Rights LAW
# Canadians NORP
# Canadians NORP
# Canadians NORP
# three years DATE
#   NORP
# the Office of the Community Outreach ORG
# Counter-radicalization Co ORG
# Parliament ORG
# Canadians NORP
# the last decade DATE
# Stephen Harper PERSON
# Canadians NORP
# Bill C-42 PERSON
# $100 million MONEY
# each year DATE
# the Canadian Firearms Advisory Committee ORG
# Stephen Harper PERSON
#   ORG
# United States GPE
# Canada GPE
# Canada GPE
# MARIJUANA GPE
# Canada GPE
# Canadians NORP
# Canadians NORP
# the Criminal Code LAW
# INDUSTRIES Canada's ORG
# Canadians NORP
# CBC/RADIO-CANADA ORG
# Stephen Harper's PERSON
# CBC/Radio-Canada ORG
# Canadians NORP
# two CARDINAL
# Stephen Harper PERSON
# Canadians NORP
# Stephen Harper's PERSON
# $150 million MONEY
# annual DATE
# CBC/Radio-Canada ORG
# Canadian NORP
# the CBC/Radio-Canada Board of Directors ORG
# Canadian NORP
# Canada GPE
# more than one million CARDINAL
# Canadians NORP
# the Harper decade DATE
# Canadian NORP
# Canadian NORP
# Canada GPE
# Targeted GPE
#   NORP
# the Canada Council for the Arts ORG
# $360 million MONEY
# each year DATE
# Telefilm Canada ORG
# the National Film Board ORG
# $25 million MONEY
# each year DATE
#   NORP
# the Promart and Trade Routes ORG
# Stephen Harper PERSON
# 25 MONEY
# each year DATE
# 40,000 CARDINAL
# the Young Canada Works ORG
# Canadians NORP
# Canada GPE
# Canada GPE
# Stephen Harper PERSON
# Anglophones PRODUCT
# the Auditor General to Supreme Court ORG
# English LANGUAGE
# French LANGUAGE
# the Official Languages Act LAW
# English LANGUAGE
# French LANGUAGE
# second ORDINAL
# the Court Challenges Program ORG
# Canada GPE
# Stephen Harper PERSON
#   ORG
# CBC/Radio-Canada ORG
# Canadians NORP
# two CARDINAL
# COMMUNITIES Canada's ORG
# HEROES PERSON
# Canadians NORP
# 300,000 MONEY
# first ORDINAL
# RESCUE GPE
# Canada GPE
# four CARDINAL
# Canada GPE
# four CARDINAL
# Canadians NORP
# Stephen Harper PERSON
# Canadians NORP
# St. John's GPE
# the Kitsilano Coast Guard Base ORG
# Vancouver GPE
# Stephen Harper PERSON
# CHAPTER FIVE LAW
# PROSPERITY Canada's ORG
# Canada GPE
# Canada GPE
# Canadians NORP
# Canada GPE
# the past decade DATE
# Stephen Harper PERSON
# Canada GPE
# 10,000 CARDINAL
# each year DATE
# almost four years DATE
# Canadian NORP
# the Express Entry ORG
# 22 CARDINAL
# 19 DATE
# Canadians NORP
# Canada GPE
# Canada GPE
# two-year DATE
# Canada GPE
# Canadian NORP
# Canadian NORP
# Canadian NORP
# Canada GPE
# Canada GPE
# Canada Post ORG
# Canada GPE
# Canadian NORP
# $1,000 Labour MONEY
# MORE COMPASSIONATE CANADA Canadians ORG
# Canada GPE
# Canada GPE
# Syria GPE
# Canada GPE
# Canadians NORP
# Syria GPE
# Canada GPE
# Hungarian NORP
# Ismaili NORP
# Muslim NORP
# South East Asia LOC
# the 1970s and 1980s DATE
# Canadians NORP
# Syria GPE
# Canada GPE
# Canada GPE
# Syria GPE
# 25,000 CARDINAL
# $250 million MONEY
# $100 million MONEY
# this fiscal year DATE
# Canada GPE
# $100 million MONEY
# this fiscal year DATE
# the United Nations High Commission for Refugees ORG
# Canada GPE
# Canada GPE
# a decade DATE
# Stephen Harper PERSON
#   NORP
# the Interim Federal Health Program ORG
#   NORP
# Canada GPE
# Immigration and Refugee Board ORG
# THE WORLD'S ORG
# the past ten years DATE
# Stephen Harper PERSON
# Africa LOC
# Canadian NORP
# Stephen Harper PERSON
# Canada GPE
# Maternal NORP
# Newborn and Child Health (MNCH ORG
# OPPORTUNITIES FOR ORG
# CANADIANS Canada's ORG
# the United States GPE
# Mexico GPE
# Conservatives NORP
# THE UNITED STATES GPE
# MEXICO LAW
# North American NORP
# the past decade DATE
# Stephen Harper PERSON
# the United States GPE
# Mexico GPE
# first ORDINAL
# Mexican NORP
# Canada GPE
# the United States GPE
# Mexico GPE
# the United States GPE
# Mexico GPE
# Canada GPE
# Building Canada Fund ORG
# the United States GPE
# Canada GPE
# Cabinet ORG
# CANADIAN NORP
# GOODS PERSON
# Canada GPE
# Canadian NORP
# 50 percent PERCENT
# Stephen Harper's PERSON
# Canadian NORP
# Canadians NORP
# Stephen Harper PERSON
# Canadians NORP
# Canadian NORP
# Canada GPE
# China GPE
# India GPE
# RENEWING CANADA'S ORG
# Canada GPE
# Canada GPE
# Armed Forces ORG
# CANADA GPE
# LEADERSHIP GPE
# WORLD ORG
# Canadian NORP
# Canada GPE
# the United Nations ORG
# the Second World War EVENT
# South African NORP
# Stephen Harper PERSON
# the United Nations ORG
# UN ORG
# Canada GPE
# Canadian NORP
# today DATE
# Canada GPE
# Canadians NORP
# Canada GPE
# Canada GPE
# Stephen Harper PERSON
# Canada GPE
# millions CARDINAL
# Canada GPE
# Canada GPE
# the United Nations ORG
# UN ORG
# French LANGUAGE
# the United Nations ORG
# the United Nations' ORG
# National Defence ORG
# Stephen Harper PERSON
# Canadian Armed Forces ORG
# more than $10 billion MONEY
# Canada GPE
# Armed Forces ORG
# Forces ORG
# years DATE
# Canada GPE
# Armed Forces ORG
# year to year DATE
# F-35 ORG
# the CF-18 fighter aircraft PRODUCT
# North America LOC
# first ORDINAL
# one CARDINAL
# Canada GPE
# ROYAL PERSON
# CANADIAN NORP
# NAVY ORG
# the Royal Canadian Navy ORG
# Navy ORG
# the National Shipbuilding and Procurement Strategy ORG
# Stephen Harper PERSON
# Navy ORG
# the Royal Canadian Navy ORG
# The Canada First Defence Strategy ORG
# Stephen Harper PERSON
# 2008 DATE
# Canada GPE
# Armed Forces ORG
# the Canadian Armed Forces ORG
# Canada GPE
# North America LOC
# the United States GPE
# North America LOC
# NORAD ORG
# the North Atlantic Treaty Organization ORG
# Canadian NORP
# Arctic LOC
# the Canadian Rangers ORG
# the United Nations ORG
# Canadians NORP
# Canadian Armed Forces ORG
# zero CARDINAL
# the Canadian Forces' Report on Transformation ORG
# The Canadian Armed Forces' ORG
# Canada GPE
# The Report on Transformation WORK_OF_ART
# the Canadian Armed Forces ORG
# IRAQ GPE
# Canada GPE
# Iraq GPE
# Canada GPE
# 25,000 CARDINAL
# Syria GPE
# CENTRAL ORG
# EASTERN ORG
# EUROPE LOC
# Canada GPE
# Central and Eastern Europe LOC
# Canada GPE
# NATO ORG
# Central and Eastern Europe LOC
# Ukraine GPE
# Canadian
# Canadian
# Canadian
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadian
# Canadian
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadian
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadian
# Canadians
# Canadians
# Canadian
# Canadians
# Canadian
# Canadian
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadian
#
#
# Canadians
# Canadians
# Canadian
# Canadians
# Canadians
# Canadians
#
# Canadian
# Canadians
# Canadians
# Harper
# CANADIAN
# Canadians
# Canadian
# Canadian
# Canadians
# Canadian
# Canadians
# Canadian
#
# Canadians
# Canadians
# Canadians
# Canadian
# Canadian
# Canadian
#
#
# Canadian
# Canadians
# Canadians
# Canadians
# Northern Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Parliamentarians
# Parliamentarians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
#
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
#
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadian
# Canadian
# Canadian
# North American
# Canadian
# Canadian
# Canadians
# Canadian
# Canadians
# Canadians
#
# Inuit
# Canadian
# Conservatives
# Canadians
# Canadians
# Canadian
# Canadians
# Inuit
# Inuit
# Canadians
# Inuit
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
#
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadian
# Canadian
# Canadians
# Canadian
# Canadian
#
#
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadians
# Canadian
# Canadians
# Canadian
# Canadian
# Canadian
# Canadian
# Canadians
# Hungarian
# Ismaili
# Muslim
# Canadians
#
#
# Canadian
# Maternal
# Conservatives
# North American
# Mexican
# CANADIAN
# Canadian
# Canadian
# Canadians
# Canadians
# Canadian
# Canadian
# South African
# Canadian
# Canadians
# CANADIAN
# Canadian
# Canadians

# %%
for ent in l_nlp.ents:
    if ent.label_ == "GPE":
        print(ent)
# Out:
# Canada
# Canada
# 12-month
# Canada
# Toronto
# Vancouver
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# British Columbia's
# Canada
# Toronto
# Alexandra Park
# Alexandra Park
# Canada
# St. John's
# Millette
# Calgary
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# C-525
# Canada
# Canada
# Quebec
# Canada
# Canada
# the United Kingdom
# Canada
# Quebec
# U.S.
# Canada
# Australia
# the United Kingdom
# CANADA
# NORTH
# Canada
# North
# Canada
# North
# Canada
# Canada
# Parliamentary
# OTTAWA
# Canada
# Parliamentary
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Paris
# Canada
# the United States
# Mexico
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# National Parks
# Canada
# National Parks
# Canada
# Canada
# Ontario
# Canada
# Canada
# Canada
# Ottawa
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# United States
# Canada
# Canada
# MARIJUANA
# Canada
# Canada
# Canada
# Targeted
# Canada
# Canada
# Canada
# RESCUE
# Canada
# Canada
# St. John's
# Vancouver
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Syria
# Canada
# Syria
# Canada
# Syria
# Canada
# Canada
# Syria
# Canada
# Canada
# Canada
# Canada
# Canada
# the United States
# Mexico
# THE UNITED STATES
# the United States
# Mexico
# Canada
# the United States
# Mexico
# the United States
# Mexico
# Canada
# the United States
# Canada
# Canada
# Canada
# China
# India
# Canada
# Canada
# CANADA
# LEADERSHIP
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# the United States
# Canada
# IRAQ
# Canada
# Iraq
# Canada
# Syria
# Canada
# Canada
# Ukraine

# %%
def get_ents(party):
    mod = nlp(party)
    ent_list = []
    for ent in mod.ents:
        if ent.label_ == "GPE":
            ent_list.append(ent)
    return ent_list

# %%
nd = get_ents(ndp)
co = get_ents(con)
gr = get_ents(gre)
li = get_ents(lib)
